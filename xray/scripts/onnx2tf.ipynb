# %%
import onnx
import tensorflow as tf
import sys
from os.path import dirname
sys.path.append(dirname("onnx-tensorflow/"))
import onnx_tf
from onnx_tf.backend import prepare

onnx_model = onnx.load("chest.onnx")  # load onnx model
onnx.checker.check_model(onnx_model)

# %%
from onnx import optimizer
# all_passes = optimizer.get_available_passes()
# print("Available optimization passes:")
# for p in all_passes:
#     print(p)
# print()

# %%
# passes = ["eliminate_identity", 
#           "eliminate_unused_initializer", 
#           "extract_constant_to_initializer",
#           "split_init",
#           "nop",
#           "fuse_consecutive_squeezes",
#           "fuse_consecutive_transposes",
#           "eliminate_nop_pad"]
#optimized_model = optimizer.optimize(onnx_model, passes)

#print('The model after optimization:\n{}'.format(optimized_model))

# One can also apply the default passes on the (serialized) model
# Check the default passes here: https://github.com/onnx/onnx/blob/master/onnx/optimizer.py#L43
optimized_model = optimizer.optimize(onnx_model)

# %%
#print('The model after optimization:\n{}'.format(optimized_model))

# %%
tf_rep = onnx_tf.backend.prepare(optimized_model, strict=False)  # prepare tf representation
tf_rep.export_graph("chest.pb")  # export the model

# %%
# import tensorflow as tf
# from __future__ import print_function
# f = tf.gfile.GFile("chest.pb", 'rb')
# graph_def = tf.GraphDef()
# graph_def.ParseFromString(f.read())
# a = tf.import_graph_def(graph_def)

# %%
def load_graph(frozen_graph_filename):
    # We load the protobuf file from the disk and parse it to retrieve the 
    # unserialized graph_def
    with tf.gfile.GFile(frozen_graph_filename, "rb") as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())

    # Then, we can use again a convenient built-in function to import a graph_def into the 
    # current default Graph
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(
            graph_def, 
            input_map=None, 
            return_elements=None, 
            name="prefix", 
            op_dict=None, 
            producer_op_list=None
        )
    return graph

# %%
graph = load_graph("chest.pb")
# Out:
# WARNING:tensorflow:From <ipython-input-11-51ab4fad8443>:17: calling import_graph_def (from tensorflow.python.framework.importer) with op_dict is deprecated and will be removed in a future version.
# Instructions for updating:
# Please file an issue at https://github.com/tensorflow/tensorflow/issues if you depend on this feature.

# %%
for op in graph.get_operations():
    print(op.name)
# Out:
# prefix/Const
# prefix/Const_1
# prefix/Const_2
# prefix/Const_3
# prefix/Const_4
# prefix/Const_5
# prefix/Const_6
# prefix/Const_7
# prefix/Const_8
# prefix/Const_9
# prefix/Const_10
# prefix/Const_11
# prefix/Const_12
# prefix/Const_13
# prefix/Const_14
# prefix/Const_15
# prefix/Const_16
# prefix/Const_17
# prefix/Const_18
# prefix/Const_19
# prefix/Const_20
# prefix/Const_21
# prefix/Const_22
# prefix/Const_23
# prefix/Const_24
# prefix/Const_25
# prefix/Const_26
# prefix/Const_27
# prefix/Const_28
# prefix/Const_29
# prefix/Const_30
# prefix/Const_31
# prefix/Const_32
# prefix/Const_33
# prefix/Const_34
# prefix/Const_35
# prefix/Const_36
# prefix/Const_37
# prefix/Const_38
# prefix/Const_39
# prefix/Const_40
# prefix/Const_41
# prefix/Const_42
# prefix/Const_43
# prefix/Const_44
# prefix/Const_45
# prefix/Const_46
# prefix/Const_47
# prefix/Const_48
# prefix/Const_49
# prefix/Const_50
# prefix/Const_51
# prefix/Const_52
# prefix/Const_53
# prefix/Const_54
# prefix/Const_55
# prefix/Const_56
# prefix/Const_57
# prefix/Const_58
# prefix/Const_59
# prefix/Const_60
# prefix/Const_61
# prefix/Const_62
# prefix/Const_63
# prefix/Const_64
# prefix/Const_65
# prefix/Const_66
# prefix/Const_67
# prefix/Const_68
# prefix/Const_69
# prefix/Const_70
# prefix/Const_71
# prefix/Const_72
# prefix/Const_73
# prefix/Const_74
# prefix/Const_75
# prefix/Const_76
# prefix/Const_77
# prefix/Const_78
# prefix/Const_79
# prefix/Const_80
# prefix/Const_81
# prefix/Const_82
# prefix/Const_83
# prefix/Const_84
# prefix/Const_85
# prefix/Const_86
# prefix/Const_87
# prefix/Const_88
# prefix/Const_89
# prefix/Const_90
# prefix/Const_91
# prefix/Const_92
# prefix/Const_93
# prefix/Const_94
# prefix/Const_95
# prefix/Const_96
# prefix/Const_97
# prefix/Const_98
# prefix/Const_99
# prefix/Const_100
# prefix/Const_101
# prefix/Const_102
# prefix/Const_103
# prefix/Const_104
# prefix/Const_105
# prefix/Const_106
# prefix/Const_107
# prefix/Const_108
# prefix/Const_109
# prefix/Const_110
# prefix/Const_111
# prefix/Const_112
# prefix/Const_113
# prefix/Const_114
# prefix/Const_115
# prefix/Const_116
# prefix/Const_117
# prefix/Const_118
# prefix/Const_119
# prefix/Const_120
# prefix/Const_121
# prefix/Const_122
# prefix/Const_123
# prefix/Const_124
# prefix/Const_125
# prefix/Const_126
# prefix/Const_127
# prefix/Const_128
# prefix/Const_129
# prefix/Const_130
# prefix/Const_131
# prefix/Const_132
# prefix/Const_133
# prefix/Const_134
# prefix/Const_135
# prefix/Const_136
# prefix/Const_137
# prefix/Const_138
# prefix/Const_139
# prefix/Const_140
# prefix/Const_141
# prefix/Const_142
# prefix/Const_143
# prefix/Const_144
# prefix/Const_145
# prefix/Const_146
# prefix/Const_147
# prefix/Const_148
# prefix/Const_149
# prefix/Const_150
# prefix/Const_151
# prefix/Const_152
# prefix/Const_153
# prefix/Const_154
# prefix/Const_155
# prefix/Const_156
# prefix/Const_157
# prefix/Const_158
# prefix/Const_159
# prefix/Const_160
# prefix/Const_161
# prefix/Const_162
# prefix/Const_163
# prefix/Const_164
# prefix/Const_165
# prefix/Const_166
# prefix/Const_167
# prefix/Const_168
# prefix/Const_169
# prefix/Const_170
# prefix/Const_171
# prefix/Const_172
# prefix/Const_173
# prefix/Const_174
# prefix/Const_175
# prefix/Const_176
# prefix/Const_177
# prefix/Const_178
# prefix/Const_179
# prefix/Const_180
# prefix/Const_181
# prefix/Const_182
# prefix/Const_183
# prefix/Const_184
# prefix/Const_185
# prefix/Const_186
# prefix/Const_187
# prefix/Const_188
# prefix/Const_189
# prefix/Const_190
# prefix/Const_191
# prefix/Const_192
# prefix/Const_193
# prefix/Const_194
# prefix/Const_195
# prefix/Const_196
# prefix/Const_197
# prefix/Const_198
# prefix/Const_199
# prefix/Const_200
# prefix/Const_201
# prefix/Const_202
# prefix/Const_203
# prefix/Const_204
# prefix/Const_205
# prefix/Const_206
# prefix/Const_207
# prefix/Const_208
# prefix/Const_209
# prefix/Const_210
# prefix/Const_211
# prefix/Const_212
# prefix/Const_213
# prefix/Const_214
# prefix/Const_215
# prefix/Const_216
# prefix/Const_217
# prefix/Const_218
# prefix/Const_219
# prefix/Const_220
# prefix/Const_221
# prefix/Const_222
# prefix/Const_223
# prefix/Const_224
# prefix/Const_225
# prefix/Const_226
# prefix/Const_227
# prefix/Const_228
# prefix/Const_229
# prefix/Const_230
# prefix/Const_231
# prefix/Const_232
# prefix/Const_233
# prefix/Const_234
# prefix/Const_235
# prefix/Const_236
# prefix/Const_237
# prefix/Const_238
# prefix/Const_239
# prefix/Const_240
# prefix/Const_241
# prefix/Const_242
# prefix/Const_243
# prefix/Const_244
# prefix/Const_245
# prefix/Const_246
# prefix/Const_247
# prefix/Const_248
# prefix/Const_249
# prefix/Const_250
# prefix/Const_251
# prefix/Const_252
# prefix/Const_253
# prefix/Const_254
# prefix/Const_255
# prefix/Const_256
# prefix/Const_257
# prefix/Const_258
# prefix/Const_259
# prefix/Const_260
# prefix/Const_261
# prefix/Const_262
# prefix/Const_263
# prefix/Const_264
# prefix/Const_265
# prefix/Const_266
# prefix/Const_267
# prefix/Const_268
# prefix/Const_269
# prefix/Const_270
# prefix/Const_271
# prefix/Const_272
# prefix/Const_273
# prefix/Const_274
# prefix/Const_275
# prefix/Const_276
# prefix/Const_277
# prefix/Const_278
# prefix/Const_279
# prefix/Const_280
# prefix/Const_281
# prefix/Const_282
# prefix/Const_283
# prefix/Const_284
# prefix/Const_285
# prefix/Const_286
# prefix/Const_287
# prefix/Const_288
# prefix/Const_289
# prefix/Const_290
# prefix/Const_291
# prefix/Const_292
# prefix/Const_293
# prefix/Const_294
# prefix/Const_295
# prefix/Const_296
# prefix/Const_297
# prefix/Const_298
# prefix/Const_299
# prefix/Const_300
# prefix/Const_301
# prefix/Const_302
# prefix/Const_303
# prefix/Const_304
# prefix/Const_305
# prefix/Const_306
# prefix/Const_307
# prefix/Const_308
# prefix/Const_309
# prefix/Const_310
# prefix/Const_311
# prefix/Const_312
# prefix/Const_313
# prefix/Const_314
# prefix/Const_315
# prefix/Const_316
# prefix/Const_317
# prefix/Const_318
# prefix/Const_319
# prefix/Const_320
# prefix/Const_321
# prefix/Const_322
# prefix/Const_323
# prefix/Const_324
# prefix/Const_325
# prefix/Const_326
# prefix/Const_327
# prefix/Const_328
# prefix/Const_329
# prefix/Const_330
# prefix/Const_331
# prefix/Const_332
# prefix/Const_333
# prefix/Const_334
# prefix/Const_335
# prefix/Const_336
# prefix/Const_337
# prefix/Const_338
# prefix/Const_339
# prefix/Const_340
# prefix/Const_341
# prefix/Const_342
# prefix/Const_343
# prefix/Const_344
# prefix/Const_345
# prefix/Const_346
# prefix/Const_347
# prefix/Const_348
# prefix/Const_349
# prefix/Const_350
# prefix/Const_351
# prefix/Const_352
# prefix/Const_353
# prefix/Const_354
# prefix/Const_355
# prefix/Const_356
# prefix/Const_357
# prefix/Const_358
# prefix/Const_359
# prefix/Const_360
# prefix/Const_361
# prefix/Const_362
# prefix/Const_363
# prefix/Const_364
# prefix/Const_365
# prefix/Const_366
# prefix/Const_367
# prefix/Const_368
# prefix/Const_369
# prefix/Const_370
# prefix/Const_371
# prefix/Const_372
# prefix/Const_373
# prefix/Const_374
# prefix/Const_375
# prefix/Const_376
# prefix/Const_377
# prefix/Const_378
# prefix/Const_379
# prefix/Const_380
# prefix/Const_381
# prefix/Const_382
# prefix/Const_383
# prefix/Const_384
# prefix/Const_385
# prefix/Const_386
# prefix/Const_387
# prefix/Const_388
# prefix/Const_389
# prefix/Const_390
# prefix/Const_391
# prefix/Const_392
# prefix/Const_393
# prefix/Const_394
# prefix/Const_395
# prefix/Const_396
# prefix/Const_397
# prefix/Const_398
# prefix/Const_399
# prefix/Const_400
# prefix/Const_401
# prefix/Const_402
# prefix/Const_403
# prefix/Const_404
# prefix/Const_405
# prefix/Const_406
# prefix/Const_407
# prefix/Const_408
# prefix/Const_409
# prefix/Const_410
# prefix/Const_411
# prefix/Const_412
# prefix/Const_413
# prefix/Const_414
# prefix/Const_415
# prefix/Const_416
# prefix/Const_417
# prefix/Const_418
# prefix/Const_419
# prefix/Const_420
# prefix/Const_421
# prefix/Const_422
# prefix/Const_423
# prefix/Const_424
# prefix/Const_425
# prefix/Const_426
# prefix/Const_427
# prefix/Const_428
# prefix/Const_429
# prefix/Const_430
# prefix/Const_431
# prefix/Const_432
# prefix/Const_433
# prefix/Const_434
# prefix/Const_435
# prefix/Const_436
# prefix/Const_437
# prefix/Const_438
# prefix/Const_439
# prefix/Const_440
# prefix/Const_441
# prefix/Const_442
# prefix/Const_443
# prefix/Const_444
# prefix/Const_445
# prefix/Const_446
# prefix/Const_447
# prefix/Const_448
# prefix/Const_449
# prefix/Const_450
# prefix/Const_451
# prefix/Const_452
# prefix/Const_453
# prefix/Const_454
# prefix/Const_455
# prefix/Const_456
# prefix/Const_457
# prefix/Const_458
# prefix/Const_459
# prefix/Const_460
# prefix/Const_461
# prefix/Const_462
# prefix/Const_463
# prefix/Const_464
# prefix/Const_465
# prefix/Const_466
# prefix/Const_467
# prefix/Const_468
# prefix/Const_469
# prefix/Const_470
# prefix/Const_471
# prefix/Const_472
# prefix/Const_473
# prefix/Const_474
# prefix/Const_475
# prefix/Const_476
# prefix/Const_477
# prefix/Const_478
# prefix/Const_479
# prefix/Const_480
# prefix/Const_481
# prefix/Const_482
# prefix/Const_483
# prefix/Const_484
# prefix/Const_485
# prefix/Const_486
# prefix/Const_487
# prefix/Const_488
# prefix/Const_489
# prefix/Const_490
# prefix/Const_491
# prefix/Const_492
# prefix/Const_493
# prefix/Const_494
# prefix/Const_495
# prefix/Const_496
# prefix/Const_497
# prefix/Const_498
# prefix/Const_499
# prefix/Const_500
# prefix/Const_501
# prefix/Const_502
# prefix/Const_503
# prefix/Const_504
# prefix/Const_505
# prefix/Const_506
# prefix/Const_507
# prefix/Const_508
# prefix/Const_509
# prefix/Const_510
# prefix/Const_511
# prefix/Const_512
# prefix/Const_513
# prefix/Const_514
# prefix/Const_515
# prefix/Const_516
# prefix/Const_517
# prefix/Const_518
# prefix/Const_519
# prefix/Const_520
# prefix/Const_521
# prefix/Const_522
# prefix/Const_523
# prefix/Const_524
# prefix/Const_525
# prefix/Const_526
# prefix/Const_527
# prefix/Const_528
# prefix/Const_529
# prefix/Const_530
# prefix/Const_531
# prefix/Const_532
# prefix/Const_533
# prefix/Const_534
# prefix/Const_535
# prefix/Const_536
# prefix/Const_537
# prefix/Const_538
# prefix/Const_539
# prefix/Const_540
# prefix/Const_541
# prefix/Const_542
# prefix/Const_543
# prefix/Const_544
# prefix/Const_545
# prefix/Const_546
# prefix/Const_547
# prefix/Const_548
# prefix/Const_549
# prefix/Const_550
# prefix/Const_551
# prefix/Const_552
# prefix/Const_553
# prefix/Const_554
# prefix/Const_555
# prefix/Const_556
# prefix/Const_557
# prefix/Const_558
# prefix/Const_559
# prefix/Const_560
# prefix/Const_561
# prefix/Const_562
# prefix/Const_563
# prefix/Const_564
# prefix/Const_565
# prefix/Const_566
# prefix/Const_567
# prefix/Const_568
# prefix/Const_569
# prefix/Const_570
# prefix/Const_571
# prefix/Const_572
# prefix/Const_573
# prefix/Const_574
# prefix/Const_575
# prefix/Const_576
# prefix/Const_577
# prefix/Const_578
# prefix/Const_579
# prefix/Const_580
# prefix/Const_581
# prefix/Const_582
# prefix/Const_583
# prefix/Const_584
# prefix/Const_585
# prefix/Const_586
# prefix/Const_587
# prefix/Const_588
# prefix/Const_589
# prefix/Const_590
# prefix/Const_591
# prefix/Const_592
# prefix/Const_593
# prefix/Const_594
# prefix/Const_595
# prefix/Const_596
# prefix/Const_597
# prefix/Const_598
# prefix/Const_599
# prefix/Const_600
# prefix/Const_601
# prefix/Const_602
# prefix/Const_603
# prefix/Const_604
# prefix/Const_605
# prefix/Const_606
# prefix/Const_607
# prefix/Const_608
# prefix/Const_609
# prefix/Const_610
# prefix/Const_611
# prefix/Const_612
# prefix/Const_613
# prefix/Const_614
# prefix/Const_615
# prefix/Const_616
# prefix/Const_617
# prefix/Const_618
# prefix/Const_619
# prefix/Const_620
# prefix/Const_621
# prefix/Const_622
# prefix/Const_623
# prefix/Const_624
# prefix/Const_625
# prefix/Const_626
# prefix/Const_627
# prefix/Const_628
# prefix/Const_629
# prefix/Const_630
# prefix/Const_631
# prefix/Const_632
# prefix/Const_633
# prefix/Const_634
# prefix/Const_635
# prefix/Const_636
# prefix/Const_637
# prefix/Const_638
# prefix/Const_639
# prefix/Const_640
# prefix/Const_641
# prefix/Const_642
# prefix/Const_643
# prefix/Const_644
# prefix/Const_645
# prefix/Const_646
# prefix/Const_647
# prefix/Const_648
# prefix/Const_649
# prefix/Const_650
# prefix/Const_651
# prefix/Const_652
# prefix/Const_653
# prefix/Const_654
# prefix/Const_655
# prefix/Const_656
# prefix/Const_657
# prefix/Const_658
# prefix/Const_659
# prefix/Const_660
# prefix/Const_661
# prefix/Const_662
# prefix/Const_663
# prefix/Const_664
# prefix/Const_665
# prefix/Const_666
# prefix/Const_667
# prefix/Const_668
# prefix/Const_669
# prefix/Const_670
# prefix/Const_671
# prefix/Const_672
# prefix/Const_673
# prefix/Const_674
# prefix/Const_675
# prefix/Const_676
# prefix/Const_677
# prefix/Const_678
# prefix/Const_679
# prefix/Const_680
# prefix/Const_681
# prefix/Const_682
# prefix/Const_683
# prefix/Const_684
# prefix/Const_685
# prefix/Const_686
# prefix/Const_687
# prefix/Const_688
# prefix/Const_689
# prefix/Const_690
# prefix/Const_691
# prefix/Const_692
# prefix/Const_693
# prefix/Const_694
# prefix/Const_695
# prefix/Const_696
# prefix/Const_697
# prefix/Const_698
# prefix/Const_699
# prefix/Const_700
# prefix/Const_701
# prefix/Const_702
# prefix/Const_703
# prefix/Const_704
# prefix/Const_705
# prefix/Const_706
# prefix/Const_707
# prefix/Const_708
# prefix/Const_709
# prefix/Const_710
# prefix/Const_711
# prefix/Const_712
# prefix/Const_713
# prefix/Const_714
# prefix/Const_715
# prefix/Const_716
# prefix/Const_717
# prefix/Const_718
# prefix/Const_719
# prefix/Const_720
# prefix/Const_721
# prefix/Const_722
# prefix/Const_723
# prefix/Const_724
# prefix/Const_725
# prefix/Const_726
# prefix/0
# prefix/transpose/perm
# prefix/transpose
# prefix/Const_727
# prefix/Pad
# prefix/Const_728
# prefix/split/split_dim
# prefix/split
# prefix/transpose_1/perm
# prefix/transpose_1
# prefix/Const_729
# prefix/split_1/split_dim
# prefix/split_1
# prefix/convolution/dilation_rate
# prefix/convolution
# prefix/concat/concat_dim
# prefix/concat
# prefix/transpose_2/perm
# prefix/transpose_2
# prefix/Reshape/shape
# prefix/Reshape
# prefix/Reshape_1/shape
# prefix/Reshape_1
# prefix/Reshape_2/shape
# prefix/Reshape_2
# prefix/Reshape_3/shape
# prefix/Reshape_3
# prefix/batchnorm/add/y
# prefix/batchnorm/add
# prefix/batchnorm/Rsqrt
# prefix/batchnorm/mul
# prefix/batchnorm/mul_1
# prefix/batchnorm/mul_2
# prefix/batchnorm/sub
# prefix/batchnorm/add_1
# prefix/Relu
# prefix/PyFunc/input_1
# prefix/PyFunc/input_2
# prefix/PyFunc/input_3
# prefix/PyFunc/input_4
# prefix/PyFunc/input_5
# prefix/PyFunc/input_6
# prefix/PyFunc
# prefix/Reshape_4/shape
# prefix/Reshape_4
# prefix/Reshape_5/shape
# prefix/Reshape_5
# prefix/Reshape_6/shape
# prefix/Reshape_6
# prefix/Reshape_7/shape
# prefix/Reshape_7
# prefix/batchnorm_1/add/y
# prefix/batchnorm_1/add
# prefix/batchnorm_1/Rsqrt
# prefix/batchnorm_1/mul
# prefix/batchnorm_1/mul_1
# prefix/batchnorm_1/mul_2
# prefix/batchnorm_1/sub
# prefix/batchnorm_1/add_1
# prefix/Relu_1
# prefix/transpose_3/perm
# prefix/transpose_3
# prefix/Const_730
# prefix/Pad_1
# prefix/Const_731
# prefix/split_2/split_dim
# prefix/split_2
# prefix/transpose_4/perm
# prefix/transpose_4
# prefix/Const_732
# prefix/split_3/split_dim
# prefix/split_3
# prefix/convolution_1/dilation_rate
# prefix/convolution_1
# prefix/concat_1/concat_dim
# prefix/concat_1
# prefix/transpose_5/perm
# prefix/transpose_5
# prefix/Reshape_8/shape
# prefix/Reshape_8
# prefix/Reshape_9/shape
# prefix/Reshape_9
# prefix/Reshape_10/shape
# prefix/Reshape_10
# prefix/Reshape_11/shape
# prefix/Reshape_11
# prefix/batchnorm_2/add/y
# prefix/batchnorm_2/add
# prefix/batchnorm_2/Rsqrt
# prefix/batchnorm_2/mul
# prefix/batchnorm_2/mul_1
# prefix/batchnorm_2/mul_2
# prefix/batchnorm_2/sub
# prefix/batchnorm_2/add_1
# prefix/Relu_2
# prefix/transpose_6/perm
# prefix/transpose_6
# prefix/Const_733
# prefix/Pad_2
# prefix/Const_734
# prefix/split_4/split_dim
# prefix/split_4
# prefix/transpose_7/perm
# prefix/transpose_7
# prefix/Const_735
# prefix/split_5/split_dim
# prefix/split_5
# prefix/convolution_2/dilation_rate
# prefix/convolution_2
# prefix/concat_2/concat_dim
# prefix/concat_2
# prefix/transpose_8/perm
# prefix/transpose_8
# prefix/concat_3/axis
# prefix/concat_3
# prefix/Reshape_12/shape
# prefix/Reshape_12
# prefix/Reshape_13/shape
# prefix/Reshape_13
# prefix/Reshape_14/shape
# prefix/Reshape_14
# prefix/Reshape_15/shape
# prefix/Reshape_15
# prefix/batchnorm_3/add/y
# prefix/batchnorm_3/add
# prefix/batchnorm_3/Rsqrt
# prefix/batchnorm_3/mul
# prefix/batchnorm_3/mul_1
# prefix/batchnorm_3/mul_2
# prefix/batchnorm_3/sub
# prefix/batchnorm_3/add_1
# prefix/Relu_3
# prefix/transpose_9/perm
# prefix/transpose_9
# prefix/Const_736
# prefix/Pad_3
# prefix/Const_737
# prefix/split_6/split_dim
# prefix/split_6
# prefix/transpose_10/perm
# prefix/transpose_10
# prefix/Const_738
# prefix/split_7/split_dim
# prefix/split_7
# prefix/convolution_3/dilation_rate
# prefix/convolution_3
# prefix/concat_4/concat_dim
# prefix/concat_4
# prefix/transpose_11/perm
# prefix/transpose_11
# prefix/Reshape_16/shape
# prefix/Reshape_16
# prefix/Reshape_17/shape
# prefix/Reshape_17
# prefix/Reshape_18/shape
# prefix/Reshape_18
# prefix/Reshape_19/shape
# prefix/Reshape_19
# prefix/batchnorm_4/add/y
# prefix/batchnorm_4/add
# prefix/batchnorm_4/Rsqrt
# prefix/batchnorm_4/mul
# prefix/batchnorm_4/mul_1
# prefix/batchnorm_4/mul_2
# prefix/batchnorm_4/sub
# prefix/batchnorm_4/add_1
# prefix/Relu_4
# prefix/transpose_12/perm
# prefix/transpose_12
# prefix/Const_739
# prefix/Pad_4
# prefix/Const_740
# prefix/split_8/split_dim
# prefix/split_8
# prefix/transpose_13/perm
# prefix/transpose_13
# prefix/Const_741
# prefix/split_9/split_dim
# prefix/split_9
# prefix/convolution_4/dilation_rate
# prefix/convolution_4
# prefix/concat_5/concat_dim
# prefix/concat_5
# prefix/transpose_14/perm
# prefix/transpose_14
# prefix/concat_6/axis
# prefix/concat_6
# prefix/Reshape_20/shape
# prefix/Reshape_20
# prefix/Reshape_21/shape
# prefix/Reshape_21
# prefix/Reshape_22/shape
# prefix/Reshape_22
# prefix/Reshape_23/shape
# prefix/Reshape_23
# prefix/batchnorm_5/add/y
# prefix/batchnorm_5/add
# prefix/batchnorm_5/Rsqrt
# prefix/batchnorm_5/mul
# prefix/batchnorm_5/mul_1
# prefix/batchnorm_5/mul_2
# prefix/batchnorm_5/sub
# prefix/batchnorm_5/add_1
# prefix/Relu_5
# prefix/transpose_15/perm
# prefix/transpose_15
# prefix/Const_742
# prefix/Pad_5
# prefix/Const_743
# prefix/split_10/split_dim
# prefix/split_10
# prefix/transpose_16/perm
# prefix/transpose_16
# prefix/Const_744
# prefix/split_11/split_dim
# prefix/split_11
# prefix/convolution_5/dilation_rate
# prefix/convolution_5
# prefix/concat_7/concat_dim
# prefix/concat_7
# prefix/transpose_17/perm
# prefix/transpose_17
# prefix/Reshape_24/shape
# prefix/Reshape_24
# prefix/Reshape_25/shape
# prefix/Reshape_25
# prefix/Reshape_26/shape
# prefix/Reshape_26
# prefix/Reshape_27/shape
# prefix/Reshape_27
# prefix/batchnorm_6/add/y
# prefix/batchnorm_6/add
# prefix/batchnorm_6/Rsqrt
# prefix/batchnorm_6/mul
# prefix/batchnorm_6/mul_1
# prefix/batchnorm_6/mul_2
# prefix/batchnorm_6/sub
# prefix/batchnorm_6/add_1
# prefix/Relu_6
# prefix/transpose_18/perm
# prefix/transpose_18
# prefix/Const_745
# prefix/Pad_6
# prefix/Const_746
# prefix/split_12/split_dim
# prefix/split_12
# prefix/transpose_19/perm
# prefix/transpose_19
# prefix/Const_747
# prefix/split_13/split_dim
# prefix/split_13
# prefix/convolution_6/dilation_rate
# prefix/convolution_6
# prefix/concat_8/concat_dim
# prefix/concat_8
# prefix/transpose_20/perm
# prefix/transpose_20
# prefix/concat_9/axis
# prefix/concat_9
# prefix/Reshape_28/shape
# prefix/Reshape_28
# prefix/Reshape_29/shape
# prefix/Reshape_29
# prefix/Reshape_30/shape
# prefix/Reshape_30
# prefix/Reshape_31/shape
# prefix/Reshape_31
# prefix/batchnorm_7/add/y
# prefix/batchnorm_7/add
# prefix/batchnorm_7/Rsqrt
# prefix/batchnorm_7/mul
# prefix/batchnorm_7/mul_1
# prefix/batchnorm_7/mul_2
# prefix/batchnorm_7/sub
# prefix/batchnorm_7/add_1
# prefix/Relu_7
# prefix/transpose_21/perm
# prefix/transpose_21
# prefix/Const_748
# prefix/Pad_7
# prefix/Const_749
# prefix/split_14/split_dim
# prefix/split_14
# prefix/transpose_22/perm
# prefix/transpose_22
# prefix/Const_750
# prefix/split_15/split_dim
# prefix/split_15
# prefix/convolution_7/dilation_rate
# prefix/convolution_7
# prefix/concat_10/concat_dim
# prefix/concat_10
# prefix/transpose_23/perm
# prefix/transpose_23
# prefix/Reshape_32/shape
# prefix/Reshape_32
# prefix/Reshape_33/shape
# prefix/Reshape_33
# prefix/Reshape_34/shape
# prefix/Reshape_34
# prefix/Reshape_35/shape
# prefix/Reshape_35
# prefix/batchnorm_8/add/y
# prefix/batchnorm_8/add
# prefix/batchnorm_8/Rsqrt
# prefix/batchnorm_8/mul
# prefix/batchnorm_8/mul_1
# prefix/batchnorm_8/mul_2
# prefix/batchnorm_8/sub
# prefix/batchnorm_8/add_1
# prefix/Relu_8
# prefix/transpose_24/perm
# prefix/transpose_24
# prefix/Const_751
# prefix/Pad_8
# prefix/Const_752
# prefix/split_16/split_dim
# prefix/split_16
# prefix/transpose_25/perm
# prefix/transpose_25
# prefix/Const_753
# prefix/split_17/split_dim
# prefix/split_17
# prefix/convolution_8/dilation_rate
# prefix/convolution_8
# prefix/concat_11/concat_dim
# prefix/concat_11
# prefix/transpose_26/perm
# prefix/transpose_26
# prefix/concat_12/axis
# prefix/concat_12
# prefix/Reshape_36/shape
# prefix/Reshape_36
# prefix/Reshape_37/shape
# prefix/Reshape_37
# prefix/Reshape_38/shape
# prefix/Reshape_38
# prefix/Reshape_39/shape
# prefix/Reshape_39
# prefix/batchnorm_9/add/y
# prefix/batchnorm_9/add
# prefix/batchnorm_9/Rsqrt
# prefix/batchnorm_9/mul
# prefix/batchnorm_9/mul_1
# prefix/batchnorm_9/mul_2
# prefix/batchnorm_9/sub
# prefix/batchnorm_9/add_1
# prefix/Relu_9
# prefix/transpose_27/perm
# prefix/transpose_27
# prefix/Const_754
# prefix/Pad_9
# prefix/Const_755
# prefix/split_18/split_dim
# prefix/split_18
# prefix/transpose_28/perm
# prefix/transpose_28
# prefix/Const_756
# prefix/split_19/split_dim
# prefix/split_19
# prefix/convolution_9/dilation_rate
# prefix/convolution_9
# prefix/concat_13/concat_dim
# prefix/concat_13
# prefix/transpose_29/perm
# prefix/transpose_29
# prefix/Reshape_40/shape
# prefix/Reshape_40
# prefix/Reshape_41/shape
# prefix/Reshape_41
# prefix/Reshape_42/shape
# prefix/Reshape_42
# prefix/Reshape_43/shape
# prefix/Reshape_43
# prefix/batchnorm_10/add/y
# prefix/batchnorm_10/add
# prefix/batchnorm_10/Rsqrt
# prefix/batchnorm_10/mul
# prefix/batchnorm_10/mul_1
# prefix/batchnorm_10/mul_2
# prefix/batchnorm_10/sub
# prefix/batchnorm_10/add_1
# prefix/Relu_10
# prefix/transpose_30/perm
# prefix/transpose_30
# prefix/Const_757
# prefix/Pad_10
# prefix/Const_758
# prefix/split_20/split_dim
# prefix/split_20
# prefix/transpose_31/perm
# prefix/transpose_31
# prefix/Const_759
# prefix/split_21/split_dim
# prefix/split_21
# prefix/convolution_10/dilation_rate
# prefix/convolution_10
# prefix/concat_14/concat_dim
# prefix/concat_14
# prefix/transpose_32/perm
# prefix/transpose_32
# prefix/concat_15/axis
# prefix/concat_15
# prefix/Reshape_44/shape
# prefix/Reshape_44
# prefix/Reshape_45/shape
# prefix/Reshape_45
# prefix/Reshape_46/shape
# prefix/Reshape_46
# prefix/Reshape_47/shape
# prefix/Reshape_47
# prefix/batchnorm_11/add/y
# prefix/batchnorm_11/add
# prefix/batchnorm_11/Rsqrt
# prefix/batchnorm_11/mul
# prefix/batchnorm_11/mul_1
# prefix/batchnorm_11/mul_2
# prefix/batchnorm_11/sub
# prefix/batchnorm_11/add_1
# prefix/Relu_11
# prefix/transpose_33/perm
# prefix/transpose_33
# prefix/Const_760
# prefix/Pad_11
# prefix/Const_761
# prefix/split_22/split_dim
# prefix/split_22
# prefix/transpose_34/perm
# prefix/transpose_34
# prefix/Const_762
# prefix/split_23/split_dim
# prefix/split_23
# prefix/convolution_11/dilation_rate
# prefix/convolution_11
# prefix/concat_16/concat_dim
# prefix/concat_16
# prefix/transpose_35/perm
# prefix/transpose_35
# prefix/Reshape_48/shape
# prefix/Reshape_48
# prefix/Reshape_49/shape
# prefix/Reshape_49
# prefix/Reshape_50/shape
# prefix/Reshape_50
# prefix/Reshape_51/shape
# prefix/Reshape_51
# prefix/batchnorm_12/add/y
# prefix/batchnorm_12/add
# prefix/batchnorm_12/Rsqrt
# prefix/batchnorm_12/mul
# prefix/batchnorm_12/mul_1
# prefix/batchnorm_12/mul_2
# prefix/batchnorm_12/sub
# prefix/batchnorm_12/add_1
# prefix/Relu_12
# prefix/transpose_36/perm
# prefix/transpose_36
# prefix/Const_763
# prefix/Pad_12
# prefix/Const_764
# prefix/split_24/split_dim
# prefix/split_24
# prefix/transpose_37/perm
# prefix/transpose_37
# prefix/Const_765
# prefix/split_25/split_dim
# prefix/split_25
# prefix/convolution_12/dilation_rate
# prefix/convolution_12
# prefix/concat_17/concat_dim
# prefix/concat_17
# prefix/transpose_38/perm
# prefix/transpose_38
# prefix/concat_18/axis
# prefix/concat_18
# prefix/Reshape_52/shape
# prefix/Reshape_52
# prefix/Reshape_53/shape
# prefix/Reshape_53
# prefix/Reshape_54/shape
# prefix/Reshape_54
# prefix/Reshape_55/shape
# prefix/Reshape_55
# prefix/batchnorm_13/add/y
# prefix/batchnorm_13/add
# prefix/batchnorm_13/Rsqrt
# prefix/batchnorm_13/mul
# prefix/batchnorm_13/mul_1
# prefix/batchnorm_13/mul_2
# prefix/batchnorm_13/sub
# prefix/batchnorm_13/add_1
# prefix/Relu_13
# prefix/transpose_39/perm
# prefix/transpose_39
# prefix/Const_766
# prefix/Pad_13
# prefix/Const_767
# prefix/split_26/split_dim
# prefix/split_26
# prefix/transpose_40/perm
# prefix/transpose_40
# prefix/Const_768
# prefix/split_27/split_dim
# prefix/split_27
# prefix/convolution_13/dilation_rate
# prefix/convolution_13
# prefix/concat_19/concat_dim
# prefix/concat_19
# prefix/transpose_41/perm
# prefix/transpose_41
# prefix/transpose_42/perm
# prefix/transpose_42
# prefix/avg_pool/dilation_rate
# prefix/avg_pool
# prefix/transpose_43/perm
# prefix/transpose_43
# prefix/Reshape_56/shape
# prefix/Reshape_56
# prefix/Reshape_57/shape
# prefix/Reshape_57
# prefix/Reshape_58/shape
# prefix/Reshape_58
# prefix/Reshape_59/shape
# prefix/Reshape_59
# prefix/batchnorm_14/add/y
# prefix/batchnorm_14/add
# prefix/batchnorm_14/Rsqrt
# prefix/batchnorm_14/mul
# prefix/batchnorm_14/mul_1
# prefix/batchnorm_14/mul_2
# prefix/batchnorm_14/sub
# prefix/batchnorm_14/add_1
# prefix/Relu_14
# prefix/transpose_44/perm
# prefix/transpose_44
# prefix/Const_769
# prefix/Pad_14
# prefix/Const_770
# prefix/split_28/split_dim
# prefix/split_28
# prefix/transpose_45/perm
# prefix/transpose_45
# prefix/Const_771
# prefix/split_29/split_dim
# prefix/split_29
# prefix/convolution_14/dilation_rate
# prefix/convolution_14
# prefix/concat_20/concat_dim
# prefix/concat_20
# prefix/transpose_46/perm
# prefix/transpose_46
# prefix/Reshape_60/shape
# prefix/Reshape_60
# prefix/Reshape_61/shape
# prefix/Reshape_61
# prefix/Reshape_62/shape
# prefix/Reshape_62
# prefix/Reshape_63/shape
# prefix/Reshape_63
# prefix/batchnorm_15/add/y
# prefix/batchnorm_15/add
# prefix/batchnorm_15/Rsqrt
# prefix/batchnorm_15/mul
# prefix/batchnorm_15/mul_1
# prefix/batchnorm_15/mul_2
# prefix/batchnorm_15/sub
# prefix/batchnorm_15/add_1
# prefix/Relu_15
# prefix/transpose_47/perm
# prefix/transpose_47
# prefix/Const_772
# prefix/Pad_15
# prefix/Const_773
# prefix/split_30/split_dim
# prefix/split_30
# prefix/transpose_48/perm
# prefix/transpose_48
# prefix/Const_774
# prefix/split_31/split_dim
# prefix/split_31
# prefix/convolution_15/dilation_rate
# prefix/convolution_15
# prefix/concat_21/concat_dim
# prefix/concat_21
# prefix/transpose_49/perm
# prefix/transpose_49
# prefix/concat_22/axis
# prefix/concat_22
# prefix/Reshape_64/shape
# prefix/Reshape_64
# prefix/Reshape_65/shape
# prefix/Reshape_65
# prefix/Reshape_66/shape
# prefix/Reshape_66
# prefix/Reshape_67/shape
# prefix/Reshape_67
# prefix/batchnorm_16/add/y
# prefix/batchnorm_16/add
# prefix/batchnorm_16/Rsqrt
# prefix/batchnorm_16/mul
# prefix/batchnorm_16/mul_1
# prefix/batchnorm_16/mul_2
# prefix/batchnorm_16/sub
# prefix/batchnorm_16/add_1
# prefix/Relu_16
# prefix/transpose_50/perm
# prefix/transpose_50
# prefix/Const_775
# prefix/Pad_16
# prefix/Const_776
# prefix/split_32/split_dim
# prefix/split_32
# prefix/transpose_51/perm
# prefix/transpose_51
# prefix/Const_777
# prefix/split_33/split_dim
# prefix/split_33
# prefix/convolution_16/dilation_rate
# prefix/convolution_16
# prefix/concat_23/concat_dim
# prefix/concat_23
# prefix/transpose_52/perm
# prefix/transpose_52
# prefix/Reshape_68/shape
# prefix/Reshape_68
# prefix/Reshape_69/shape
# prefix/Reshape_69
# prefix/Reshape_70/shape
# prefix/Reshape_70
# prefix/Reshape_71/shape
# prefix/Reshape_71
# prefix/batchnorm_17/add/y
# prefix/batchnorm_17/add
# prefix/batchnorm_17/Rsqrt
# prefix/batchnorm_17/mul
# prefix/batchnorm_17/mul_1
# prefix/batchnorm_17/mul_2
# prefix/batchnorm_17/sub
# prefix/batchnorm_17/add_1
# prefix/Relu_17
# prefix/transpose_53/perm
# prefix/transpose_53
# prefix/Const_778
# prefix/Pad_17
# prefix/Const_779
# prefix/split_34/split_dim
# prefix/split_34
# prefix/transpose_54/perm
# prefix/transpose_54
# prefix/Const_780
# prefix/split_35/split_dim
# prefix/split_35
# prefix/convolution_17/dilation_rate
# prefix/convolution_17
# prefix/concat_24/concat_dim
# prefix/concat_24
# prefix/transpose_55/perm
# prefix/transpose_55
# prefix/concat_25/axis
# prefix/concat_25
# prefix/Reshape_72/shape
# prefix/Reshape_72
# prefix/Reshape_73/shape
# prefix/Reshape_73
# prefix/Reshape_74/shape
# prefix/Reshape_74
# prefix/Reshape_75/shape
# prefix/Reshape_75
# prefix/batchnorm_18/add/y
# prefix/batchnorm_18/add
# prefix/batchnorm_18/Rsqrt
# prefix/batchnorm_18/mul
# prefix/batchnorm_18/mul_1
# prefix/batchnorm_18/mul_2
# prefix/batchnorm_18/sub
# prefix/batchnorm_18/add_1
# prefix/Relu_18
# prefix/transpose_56/perm
# prefix/transpose_56
# prefix/Const_781
# prefix/Pad_18
# prefix/Const_782
# prefix/split_36/split_dim
# prefix/split_36
# prefix/transpose_57/perm
# prefix/transpose_57
# prefix/Const_783
# prefix/split_37/split_dim
# prefix/split_37
# prefix/convolution_18/dilation_rate
# prefix/convolution_18
# prefix/concat_26/concat_dim
# prefix/concat_26
# prefix/transpose_58/perm
# prefix/transpose_58
# prefix/Reshape_76/shape
# prefix/Reshape_76
# prefix/Reshape_77/shape
# prefix/Reshape_77
# prefix/Reshape_78/shape
# prefix/Reshape_78
# prefix/Reshape_79/shape
# prefix/Reshape_79
# prefix/batchnorm_19/add/y
# prefix/batchnorm_19/add
# prefix/batchnorm_19/Rsqrt
# prefix/batchnorm_19/mul
# prefix/batchnorm_19/mul_1
# prefix/batchnorm_19/mul_2
# prefix/batchnorm_19/sub
# prefix/batchnorm_19/add_1
# prefix/Relu_19
# prefix/transpose_59/perm
# prefix/transpose_59
# prefix/Const_784
# prefix/Pad_19
# prefix/Const_785
# prefix/split_38/split_dim
# prefix/split_38
# prefix/transpose_60/perm
# prefix/transpose_60
# prefix/Const_786
# prefix/split_39/split_dim
# prefix/split_39
# prefix/convolution_19/dilation_rate
# prefix/convolution_19
# prefix/concat_27/concat_dim
# prefix/concat_27
# prefix/transpose_61/perm
# prefix/transpose_61
# prefix/concat_28/axis
# prefix/concat_28
# prefix/Reshape_80/shape
# prefix/Reshape_80
# prefix/Reshape_81/shape
# prefix/Reshape_81
# prefix/Reshape_82/shape
# prefix/Reshape_82
# prefix/Reshape_83/shape
# prefix/Reshape_83
# prefix/batchnorm_20/add/y
# prefix/batchnorm_20/add
# prefix/batchnorm_20/Rsqrt
# prefix/batchnorm_20/mul
# prefix/batchnorm_20/mul_1
# prefix/batchnorm_20/mul_2
# prefix/batchnorm_20/sub
# prefix/batchnorm_20/add_1
# prefix/Relu_20
# prefix/transpose_62/perm
# prefix/transpose_62
# prefix/Const_787
# prefix/Pad_20
# prefix/Const_788
# prefix/split_40/split_dim
# prefix/split_40
# prefix/transpose_63/perm
# prefix/transpose_63
# prefix/Const_789
# prefix/split_41/split_dim
# prefix/split_41
# prefix/convolution_20/dilation_rate
# prefix/convolution_20
# prefix/concat_29/concat_dim
# prefix/concat_29
# prefix/transpose_64/perm
# prefix/transpose_64
# prefix/Reshape_84/shape
# prefix/Reshape_84
# prefix/Reshape_85/shape
# prefix/Reshape_85
# prefix/Reshape_86/shape
# prefix/Reshape_86
# prefix/Reshape_87/shape
# prefix/Reshape_87
# prefix/batchnorm_21/add/y
# prefix/batchnorm_21/add
# prefix/batchnorm_21/Rsqrt
# prefix/batchnorm_21/mul
# prefix/batchnorm_21/mul_1
# prefix/batchnorm_21/mul_2
# prefix/batchnorm_21/sub
# prefix/batchnorm_21/add_1
# prefix/Relu_21
# prefix/transpose_65/perm
# prefix/transpose_65
# prefix/Const_790
# prefix/Pad_21
# prefix/Const_791
# prefix/split_42/split_dim
# prefix/split_42
# prefix/transpose_66/perm
# prefix/transpose_66
# prefix/Const_792
# prefix/split_43/split_dim
# prefix/split_43
# prefix/convolution_21/dilation_rate
# prefix/convolution_21
# prefix/concat_30/concat_dim
# prefix/concat_30
# prefix/transpose_67/perm
# prefix/transpose_67
# prefix/concat_31/axis
# prefix/concat_31
# prefix/Reshape_88/shape
# prefix/Reshape_88
# prefix/Reshape_89/shape
# prefix/Reshape_89
# prefix/Reshape_90/shape
# prefix/Reshape_90
# prefix/Reshape_91/shape
# prefix/Reshape_91
# prefix/batchnorm_22/add/y
# prefix/batchnorm_22/add
# prefix/batchnorm_22/Rsqrt
# prefix/batchnorm_22/mul
# prefix/batchnorm_22/mul_1
# prefix/batchnorm_22/mul_2
# prefix/batchnorm_22/sub
# prefix/batchnorm_22/add_1
# prefix/Relu_22
# prefix/transpose_68/perm
# prefix/transpose_68
# prefix/Const_793
# prefix/Pad_22
# prefix/Const_794
# prefix/split_44/split_dim
# prefix/split_44
# prefix/transpose_69/perm
# prefix/transpose_69
# prefix/Const_795
# prefix/split_45/split_dim
# prefix/split_45
# prefix/convolution_22/dilation_rate
# prefix/convolution_22
# prefix/concat_32/concat_dim
# prefix/concat_32
# prefix/transpose_70/perm
# prefix/transpose_70
# prefix/Reshape_92/shape
# prefix/Reshape_92
# prefix/Reshape_93/shape
# prefix/Reshape_93
# prefix/Reshape_94/shape
# prefix/Reshape_94
# prefix/Reshape_95/shape
# prefix/Reshape_95
# prefix/batchnorm_23/add/y
# prefix/batchnorm_23/add
# prefix/batchnorm_23/Rsqrt
# prefix/batchnorm_23/mul
# prefix/batchnorm_23/mul_1
# prefix/batchnorm_23/mul_2
# prefix/batchnorm_23/sub
# prefix/batchnorm_23/add_1
# prefix/Relu_23
# prefix/transpose_71/perm
# prefix/transpose_71
# prefix/Const_796
# prefix/Pad_23
# prefix/Const_797
# prefix/split_46/split_dim
# prefix/split_46
# prefix/transpose_72/perm
# prefix/transpose_72
# prefix/Const_798
# prefix/split_47/split_dim
# prefix/split_47
# prefix/convolution_23/dilation_rate
# prefix/convolution_23
# prefix/concat_33/concat_dim
# prefix/concat_33
# prefix/transpose_73/perm
# prefix/transpose_73
# prefix/concat_34/axis
# prefix/concat_34
# prefix/Reshape_96/shape
# prefix/Reshape_96
# prefix/Reshape_97/shape
# prefix/Reshape_97
# prefix/Reshape_98/shape
# prefix/Reshape_98
# prefix/Reshape_99/shape
# prefix/Reshape_99
# prefix/batchnorm_24/add/y
# prefix/batchnorm_24/add
# prefix/batchnorm_24/Rsqrt
# prefix/batchnorm_24/mul
# prefix/batchnorm_24/mul_1
# prefix/batchnorm_24/mul_2
# prefix/batchnorm_24/sub
# prefix/batchnorm_24/add_1
# prefix/Relu_24
# prefix/transpose_74/perm
# prefix/transpose_74
# prefix/Const_799
# prefix/Pad_24
# prefix/Const_800
# prefix/split_48/split_dim
# prefix/split_48
# prefix/transpose_75/perm
# prefix/transpose_75
# prefix/Const_801
# prefix/split_49/split_dim
# prefix/split_49
# prefix/convolution_24/dilation_rate
# prefix/convolution_24
# prefix/concat_35/concat_dim
# prefix/concat_35
# prefix/transpose_76/perm
# prefix/transpose_76
# prefix/Reshape_100/shape
# prefix/Reshape_100
# prefix/Reshape_101/shape
# prefix/Reshape_101
# prefix/Reshape_102/shape
# prefix/Reshape_102
# prefix/Reshape_103/shape
# prefix/Reshape_103
# prefix/batchnorm_25/add/y
# prefix/batchnorm_25/add
# prefix/batchnorm_25/Rsqrt
# prefix/batchnorm_25/mul
# prefix/batchnorm_25/mul_1
# prefix/batchnorm_25/mul_2
# prefix/batchnorm_25/sub
# prefix/batchnorm_25/add_1
# prefix/Relu_25
# prefix/transpose_77/perm
# prefix/transpose_77
# prefix/Const_802
# prefix/Pad_25
# prefix/Const_803
# prefix/split_50/split_dim
# prefix/split_50
# prefix/transpose_78/perm
# prefix/transpose_78
# prefix/Const_804
# prefix/split_51/split_dim
# prefix/split_51
# prefix/convolution_25/dilation_rate
# prefix/convolution_25
# prefix/concat_36/concat_dim
# prefix/concat_36
# prefix/transpose_79/perm
# prefix/transpose_79
# prefix/concat_37/axis
# prefix/concat_37
# prefix/Reshape_104/shape
# prefix/Reshape_104
# prefix/Reshape_105/shape
# prefix/Reshape_105
# prefix/Reshape_106/shape
# prefix/Reshape_106
# prefix/Reshape_107/shape
# prefix/Reshape_107
# prefix/batchnorm_26/add/y
# prefix/batchnorm_26/add
# prefix/batchnorm_26/Rsqrt
# prefix/batchnorm_26/mul
# prefix/batchnorm_26/mul_1
# prefix/batchnorm_26/mul_2
# prefix/batchnorm_26/sub
# prefix/batchnorm_26/add_1
# prefix/Relu_26
# prefix/transpose_80/perm
# prefix/transpose_80
# prefix/Const_805
# prefix/Pad_26
# prefix/Const_806
# prefix/split_52/split_dim
# prefix/split_52
# prefix/transpose_81/perm
# prefix/transpose_81
# prefix/Const_807
# prefix/split_53/split_dim
# prefix/split_53
# prefix/convolution_26/dilation_rate
# prefix/convolution_26
# prefix/concat_38/concat_dim
# prefix/concat_38
# prefix/transpose_82/perm
# prefix/transpose_82
# prefix/Reshape_108/shape
# prefix/Reshape_108
# prefix/Reshape_109/shape
# prefix/Reshape_109
# prefix/Reshape_110/shape
# prefix/Reshape_110
# prefix/Reshape_111/shape
# prefix/Reshape_111
# prefix/batchnorm_27/add/y
# prefix/batchnorm_27/add
# prefix/batchnorm_27/Rsqrt
# prefix/batchnorm_27/mul
# prefix/batchnorm_27/mul_1
# prefix/batchnorm_27/mul_2
# prefix/batchnorm_27/sub
# prefix/batchnorm_27/add_1
# prefix/Relu_27
# prefix/transpose_83/perm
# prefix/transpose_83
# prefix/Const_808
# prefix/Pad_27
# prefix/Const_809
# prefix/split_54/split_dim
# prefix/split_54
# prefix/transpose_84/perm
# prefix/transpose_84
# prefix/Const_810
# prefix/split_55/split_dim
# prefix/split_55
# prefix/convolution_27/dilation_rate
# prefix/convolution_27
# prefix/concat_39/concat_dim
# prefix/concat_39
# prefix/transpose_85/perm
# prefix/transpose_85
# prefix/concat_40/axis
# prefix/concat_40
# prefix/Reshape_112/shape
# prefix/Reshape_112
# prefix/Reshape_113/shape
# prefix/Reshape_113
# prefix/Reshape_114/shape
# prefix/Reshape_114
# prefix/Reshape_115/shape
# prefix/Reshape_115
# prefix/batchnorm_28/add/y
# prefix/batchnorm_28/add
# prefix/batchnorm_28/Rsqrt
# prefix/batchnorm_28/mul
# prefix/batchnorm_28/mul_1
# prefix/batchnorm_28/mul_2
# prefix/batchnorm_28/sub
# prefix/batchnorm_28/add_1
# prefix/Relu_28
# prefix/transpose_86/perm
# prefix/transpose_86
# prefix/Const_811
# prefix/Pad_28
# prefix/Const_812
# prefix/split_56/split_dim
# prefix/split_56
# prefix/transpose_87/perm
# prefix/transpose_87
# prefix/Const_813
# prefix/split_57/split_dim
# prefix/split_57
# prefix/convolution_28/dilation_rate
# prefix/convolution_28
# prefix/concat_41/concat_dim
# prefix/concat_41
# prefix/transpose_88/perm
# prefix/transpose_88
# prefix/Reshape_116/shape
# prefix/Reshape_116
# prefix/Reshape_117/shape
# prefix/Reshape_117
# prefix/Reshape_118/shape
# prefix/Reshape_118
# prefix/Reshape_119/shape
# prefix/Reshape_119
# prefix/batchnorm_29/add/y
# prefix/batchnorm_29/add
# prefix/batchnorm_29/Rsqrt
# prefix/batchnorm_29/mul
# prefix/batchnorm_29/mul_1
# prefix/batchnorm_29/mul_2
# prefix/batchnorm_29/sub
# prefix/batchnorm_29/add_1
# prefix/Relu_29
# prefix/transpose_89/perm
# prefix/transpose_89
# prefix/Const_814
# prefix/Pad_29
# prefix/Const_815
# prefix/split_58/split_dim
# prefix/split_58
# prefix/transpose_90/perm
# prefix/transpose_90
# prefix/Const_816
# prefix/split_59/split_dim
# prefix/split_59
# prefix/convolution_29/dilation_rate
# prefix/convolution_29
# prefix/concat_42/concat_dim
# prefix/concat_42
# prefix/transpose_91/perm
# prefix/transpose_91
# prefix/concat_43/axis
# prefix/concat_43
# prefix/Reshape_120/shape
# prefix/Reshape_120
# prefix/Reshape_121/shape
# prefix/Reshape_121
# prefix/Reshape_122/shape
# prefix/Reshape_122
# prefix/Reshape_123/shape
# prefix/Reshape_123
# prefix/batchnorm_30/add/y
# prefix/batchnorm_30/add
# prefix/batchnorm_30/Rsqrt
# prefix/batchnorm_30/mul
# prefix/batchnorm_30/mul_1
# prefix/batchnorm_30/mul_2
# prefix/batchnorm_30/sub
# prefix/batchnorm_30/add_1
# prefix/Relu_30
# prefix/transpose_92/perm
# prefix/transpose_92
# prefix/Const_817
# prefix/Pad_30
# prefix/Const_818
# prefix/split_60/split_dim
# prefix/split_60
# prefix/transpose_93/perm
# prefix/transpose_93
# prefix/Const_819
# prefix/split_61/split_dim
# prefix/split_61
# prefix/convolution_30/dilation_rate
# prefix/convolution_30
# prefix/concat_44/concat_dim
# prefix/concat_44
# prefix/transpose_94/perm
# prefix/transpose_94
# prefix/Reshape_124/shape
# prefix/Reshape_124
# prefix/Reshape_125/shape
# prefix/Reshape_125
# prefix/Reshape_126/shape
# prefix/Reshape_126
# prefix/Reshape_127/shape
# prefix/Reshape_127
# prefix/batchnorm_31/add/y
# prefix/batchnorm_31/add
# prefix/batchnorm_31/Rsqrt
# prefix/batchnorm_31/mul
# prefix/batchnorm_31/mul_1
# prefix/batchnorm_31/mul_2
# prefix/batchnorm_31/sub
# prefix/batchnorm_31/add_1
# prefix/Relu_31
# prefix/transpose_95/perm
# prefix/transpose_95
# prefix/Const_820
# prefix/Pad_31
# prefix/Const_821
# prefix/split_62/split_dim
# prefix/split_62
# prefix/transpose_96/perm
# prefix/transpose_96
# prefix/Const_822
# prefix/split_63/split_dim
# prefix/split_63
# prefix/convolution_31/dilation_rate
# prefix/convolution_31
# prefix/concat_45/concat_dim
# prefix/concat_45
# prefix/transpose_97/perm
# prefix/transpose_97
# prefix/concat_46/axis
# prefix/concat_46
# prefix/Reshape_128/shape
# prefix/Reshape_128
# prefix/Reshape_129/shape
# prefix/Reshape_129
# prefix/Reshape_130/shape
# prefix/Reshape_130
# prefix/Reshape_131/shape
# prefix/Reshape_131
# prefix/batchnorm_32/add/y
# prefix/batchnorm_32/add
# prefix/batchnorm_32/Rsqrt
# prefix/batchnorm_32/mul
# prefix/batchnorm_32/mul_1
# prefix/batchnorm_32/mul_2
# prefix/batchnorm_32/sub
# prefix/batchnorm_32/add_1
# prefix/Relu_32
# prefix/transpose_98/perm
# prefix/transpose_98
# prefix/Const_823
# prefix/Pad_32
# prefix/Const_824
# prefix/split_64/split_dim
# prefix/split_64
# prefix/transpose_99/perm
# prefix/transpose_99
# prefix/Const_825
# prefix/split_65/split_dim
# prefix/split_65
# prefix/convolution_32/dilation_rate
# prefix/convolution_32
# prefix/concat_47/concat_dim
# prefix/concat_47
# prefix/transpose_100/perm
# prefix/transpose_100
# prefix/Reshape_132/shape
# prefix/Reshape_132
# prefix/Reshape_133/shape
# prefix/Reshape_133
# prefix/Reshape_134/shape
# prefix/Reshape_134
# prefix/Reshape_135/shape
# prefix/Reshape_135
# prefix/batchnorm_33/add/y
# prefix/batchnorm_33/add
# prefix/batchnorm_33/Rsqrt
# prefix/batchnorm_33/mul
# prefix/batchnorm_33/mul_1
# prefix/batchnorm_33/mul_2
# prefix/batchnorm_33/sub
# prefix/batchnorm_33/add_1
# prefix/Relu_33
# prefix/transpose_101/perm
# prefix/transpose_101
# prefix/Const_826
# prefix/Pad_33
# prefix/Const_827
# prefix/split_66/split_dim
# prefix/split_66
# prefix/transpose_102/perm
# prefix/transpose_102
# prefix/Const_828
# prefix/split_67/split_dim
# prefix/split_67
# prefix/convolution_33/dilation_rate
# prefix/convolution_33
# prefix/concat_48/concat_dim
# prefix/concat_48
# prefix/transpose_103/perm
# prefix/transpose_103
# prefix/concat_49/axis
# prefix/concat_49
# prefix/Reshape_136/shape
# prefix/Reshape_136
# prefix/Reshape_137/shape
# prefix/Reshape_137
# prefix/Reshape_138/shape
# prefix/Reshape_138
# prefix/Reshape_139/shape
# prefix/Reshape_139
# prefix/batchnorm_34/add/y
# prefix/batchnorm_34/add
# prefix/batchnorm_34/Rsqrt
# prefix/batchnorm_34/mul
# prefix/batchnorm_34/mul_1
# prefix/batchnorm_34/mul_2
# prefix/batchnorm_34/sub
# prefix/batchnorm_34/add_1
# prefix/Relu_34
# prefix/transpose_104/perm
# prefix/transpose_104
# prefix/Const_829
# prefix/Pad_34
# prefix/Const_830
# prefix/split_68/split_dim
# prefix/split_68
# prefix/transpose_105/perm
# prefix/transpose_105
# prefix/Const_831
# prefix/split_69/split_dim
# prefix/split_69
# prefix/convolution_34/dilation_rate
# prefix/convolution_34
# prefix/concat_50/concat_dim
# prefix/concat_50
# prefix/transpose_106/perm
# prefix/transpose_106
# prefix/Reshape_140/shape
# prefix/Reshape_140
# prefix/Reshape_141/shape
# prefix/Reshape_141
# prefix/Reshape_142/shape
# prefix/Reshape_142
# prefix/Reshape_143/shape
# prefix/Reshape_143
# prefix/batchnorm_35/add/y
# prefix/batchnorm_35/add
# prefix/batchnorm_35/Rsqrt
# prefix/batchnorm_35/mul
# prefix/batchnorm_35/mul_1
# prefix/batchnorm_35/mul_2
# prefix/batchnorm_35/sub
# prefix/batchnorm_35/add_1
# prefix/Relu_35
# prefix/transpose_107/perm
# prefix/transpose_107
# prefix/Const_832
# prefix/Pad_35
# prefix/Const_833
# prefix/split_70/split_dim
# prefix/split_70
# prefix/transpose_108/perm
# prefix/transpose_108
# prefix/Const_834
# prefix/split_71/split_dim
# prefix/split_71
# prefix/convolution_35/dilation_rate
# prefix/convolution_35
# prefix/concat_51/concat_dim
# prefix/concat_51
# prefix/transpose_109/perm
# prefix/transpose_109
# prefix/concat_52/axis
# prefix/concat_52
# prefix/Reshape_144/shape
# prefix/Reshape_144
# prefix/Reshape_145/shape
# prefix/Reshape_145
# prefix/Reshape_146/shape
# prefix/Reshape_146
# prefix/Reshape_147/shape
# prefix/Reshape_147
# prefix/batchnorm_36/add/y
# prefix/batchnorm_36/add
# prefix/batchnorm_36/Rsqrt
# prefix/batchnorm_36/mul
# prefix/batchnorm_36/mul_1
# prefix/batchnorm_36/mul_2
# prefix/batchnorm_36/sub
# prefix/batchnorm_36/add_1
# prefix/Relu_36
# prefix/transpose_110/perm
# prefix/transpose_110
# prefix/Const_835
# prefix/Pad_36
# prefix/Const_836
# prefix/split_72/split_dim
# prefix/split_72
# prefix/transpose_111/perm
# prefix/transpose_111
# prefix/Const_837
# prefix/split_73/split_dim
# prefix/split_73
# prefix/convolution_36/dilation_rate
# prefix/convolution_36
# prefix/concat_53/concat_dim
# prefix/concat_53
# prefix/transpose_112/perm
# prefix/transpose_112
# prefix/Reshape_148/shape
# prefix/Reshape_148
# prefix/Reshape_149/shape
# prefix/Reshape_149
# prefix/Reshape_150/shape
# prefix/Reshape_150
# prefix/Reshape_151/shape
# prefix/Reshape_151
# prefix/batchnorm_37/add/y
# prefix/batchnorm_37/add
# prefix/batchnorm_37/Rsqrt
# prefix/batchnorm_37/mul
# prefix/batchnorm_37/mul_1
# prefix/batchnorm_37/mul_2
# prefix/batchnorm_37/sub
# prefix/batchnorm_37/add_1
# prefix/Relu_37
# prefix/transpose_113/perm
# prefix/transpose_113
# prefix/Const_838
# prefix/Pad_37
# prefix/Const_839
# prefix/split_74/split_dim
# prefix/split_74
# prefix/transpose_114/perm
# prefix/transpose_114
# prefix/Const_840
# prefix/split_75/split_dim
# prefix/split_75
# prefix/convolution_37/dilation_rate
# prefix/convolution_37
# prefix/concat_54/concat_dim
# prefix/concat_54
# prefix/transpose_115/perm
# prefix/transpose_115
# prefix/concat_55/axis
# prefix/concat_55
# prefix/Reshape_152/shape
# prefix/Reshape_152
# prefix/Reshape_153/shape
# prefix/Reshape_153
# prefix/Reshape_154/shape
# prefix/Reshape_154
# prefix/Reshape_155/shape
# prefix/Reshape_155
# prefix/batchnorm_38/add/y
# prefix/batchnorm_38/add
# prefix/batchnorm_38/Rsqrt
# prefix/batchnorm_38/mul
# prefix/batchnorm_38/mul_1
# prefix/batchnorm_38/mul_2
# prefix/batchnorm_38/sub
# prefix/batchnorm_38/add_1
# prefix/Relu_38
# prefix/transpose_116/perm
# prefix/transpose_116
# prefix/Const_841
# prefix/Pad_38
# prefix/Const_842
# prefix/split_76/split_dim
# prefix/split_76
# prefix/transpose_117/perm
# prefix/transpose_117
# prefix/Const_843
# prefix/split_77/split_dim
# prefix/split_77
# prefix/convolution_38/dilation_rate
# prefix/convolution_38
# prefix/concat_56/concat_dim
# prefix/concat_56
# prefix/transpose_118/perm
# prefix/transpose_118
# prefix/transpose_119/perm
# prefix/transpose_119
# prefix/avg_pool_1/dilation_rate
# prefix/avg_pool_1
# prefix/transpose_120/perm
# prefix/transpose_120
# prefix/Reshape_156/shape
# prefix/Reshape_156
# prefix/Reshape_157/shape
# prefix/Reshape_157
# prefix/Reshape_158/shape
# prefix/Reshape_158
# prefix/Reshape_159/shape
# prefix/Reshape_159
# prefix/batchnorm_39/add/y
# prefix/batchnorm_39/add
# prefix/batchnorm_39/Rsqrt
# prefix/batchnorm_39/mul
# prefix/batchnorm_39/mul_1
# prefix/batchnorm_39/mul_2
# prefix/batchnorm_39/sub
# prefix/batchnorm_39/add_1
# prefix/Relu_39
# prefix/transpose_121/perm
# prefix/transpose_121
# prefix/Const_844
# prefix/Pad_39
# prefix/Const_845
# prefix/split_78/split_dim
# prefix/split_78
# prefix/transpose_122/perm
# prefix/transpose_122
# prefix/Const_846
# prefix/split_79/split_dim
# prefix/split_79
# prefix/convolution_39/dilation_rate
# prefix/convolution_39
# prefix/concat_57/concat_dim
# prefix/concat_57
# prefix/transpose_123/perm
# prefix/transpose_123
# prefix/Reshape_160/shape
# prefix/Reshape_160
# prefix/Reshape_161/shape
# prefix/Reshape_161
# prefix/Reshape_162/shape
# prefix/Reshape_162
# prefix/Reshape_163/shape
# prefix/Reshape_163
# prefix/batchnorm_40/add/y
# prefix/batchnorm_40/add
# prefix/batchnorm_40/Rsqrt
# prefix/batchnorm_40/mul
# prefix/batchnorm_40/mul_1
# prefix/batchnorm_40/mul_2
# prefix/batchnorm_40/sub
# prefix/batchnorm_40/add_1
# prefix/Relu_40
# prefix/transpose_124/perm
# prefix/transpose_124
# prefix/Const_847
# prefix/Pad_40
# prefix/Const_848
# prefix/split_80/split_dim
# prefix/split_80
# prefix/transpose_125/perm
# prefix/transpose_125
# prefix/Const_849
# prefix/split_81/split_dim
# prefix/split_81
# prefix/convolution_40/dilation_rate
# prefix/convolution_40
# prefix/concat_58/concat_dim
# prefix/concat_58
# prefix/transpose_126/perm
# prefix/transpose_126
# prefix/concat_59/axis
# prefix/concat_59
# prefix/Reshape_164/shape
# prefix/Reshape_164
# prefix/Reshape_165/shape
# prefix/Reshape_165
# prefix/Reshape_166/shape
# prefix/Reshape_166
# prefix/Reshape_167/shape
# prefix/Reshape_167
# prefix/batchnorm_41/add/y
# prefix/batchnorm_41/add
# prefix/batchnorm_41/Rsqrt
# prefix/batchnorm_41/mul
# prefix/batchnorm_41/mul_1
# prefix/batchnorm_41/mul_2
# prefix/batchnorm_41/sub
# prefix/batchnorm_41/add_1
# prefix/Relu_41
# prefix/transpose_127/perm
# prefix/transpose_127
# prefix/Const_850
# prefix/Pad_41
# prefix/Const_851
# prefix/split_82/split_dim
# prefix/split_82
# prefix/transpose_128/perm
# prefix/transpose_128
# prefix/Const_852
# prefix/split_83/split_dim
# prefix/split_83
# prefix/convolution_41/dilation_rate
# prefix/convolution_41
# prefix/concat_60/concat_dim
# prefix/concat_60
# prefix/transpose_129/perm
# prefix/transpose_129
# prefix/Reshape_168/shape
# prefix/Reshape_168
# prefix/Reshape_169/shape
# prefix/Reshape_169
# prefix/Reshape_170/shape
# prefix/Reshape_170
# prefix/Reshape_171/shape
# prefix/Reshape_171
# prefix/batchnorm_42/add/y
# prefix/batchnorm_42/add
# prefix/batchnorm_42/Rsqrt
# prefix/batchnorm_42/mul
# prefix/batchnorm_42/mul_1
# prefix/batchnorm_42/mul_2
# prefix/batchnorm_42/sub
# prefix/batchnorm_42/add_1
# prefix/Relu_42
# prefix/transpose_130/perm
# prefix/transpose_130
# prefix/Const_853
# prefix/Pad_42
# prefix/Const_854
# prefix/split_84/split_dim
# prefix/split_84
# prefix/transpose_131/perm
# prefix/transpose_131
# prefix/Const_855
# prefix/split_85/split_dim
# prefix/split_85
# prefix/convolution_42/dilation_rate
# prefix/convolution_42
# prefix/concat_61/concat_dim
# prefix/concat_61
# prefix/transpose_132/perm
# prefix/transpose_132
# prefix/concat_62/axis
# prefix/concat_62
# prefix/Reshape_172/shape
# prefix/Reshape_172
# prefix/Reshape_173/shape
# prefix/Reshape_173
# prefix/Reshape_174/shape
# prefix/Reshape_174
# prefix/Reshape_175/shape
# prefix/Reshape_175
# prefix/batchnorm_43/add/y
# prefix/batchnorm_43/add
# prefix/batchnorm_43/Rsqrt
# prefix/batchnorm_43/mul
# prefix/batchnorm_43/mul_1
# prefix/batchnorm_43/mul_2
# prefix/batchnorm_43/sub
# prefix/batchnorm_43/add_1
# prefix/Relu_43
# prefix/transpose_133/perm
# prefix/transpose_133
# prefix/Const_856
# prefix/Pad_43
# prefix/Const_857
# prefix/split_86/split_dim
# prefix/split_86
# prefix/transpose_134/perm
# prefix/transpose_134
# prefix/Const_858
# prefix/split_87/split_dim
# prefix/split_87
# prefix/convolution_43/dilation_rate
# prefix/convolution_43
# prefix/concat_63/concat_dim
# prefix/concat_63
# prefix/transpose_135/perm
# prefix/transpose_135
# prefix/Reshape_176/shape
# prefix/Reshape_176
# prefix/Reshape_177/shape
# prefix/Reshape_177
# prefix/Reshape_178/shape
# prefix/Reshape_178
# prefix/Reshape_179/shape
# prefix/Reshape_179
# prefix/batchnorm_44/add/y
# prefix/batchnorm_44/add
# prefix/batchnorm_44/Rsqrt
# prefix/batchnorm_44/mul
# prefix/batchnorm_44/mul_1
# prefix/batchnorm_44/mul_2
# prefix/batchnorm_44/sub
# prefix/batchnorm_44/add_1
# prefix/Relu_44
# prefix/transpose_136/perm
# prefix/transpose_136
# prefix/Const_859
# prefix/Pad_44
# prefix/Const_860
# prefix/split_88/split_dim
# prefix/split_88
# prefix/transpose_137/perm
# prefix/transpose_137
# ...
# prefix/Const_1033
# prefix/Pad_102
# prefix/Const_1034
# prefix/split_204/split_dim
# prefix/split_204
# prefix/transpose_313/perm
# prefix/transpose_313
# prefix/Const_1035
# prefix/split_205/split_dim
# prefix/split_205
# prefix/convolution_102/dilation_rate
# prefix/convolution_102
# prefix/concat_151/concat_dim
# prefix/concat_151
# prefix/transpose_314/perm
# prefix/transpose_314
# prefix/Reshape_412/shape
# prefix/Reshape_412
# prefix/Reshape_413/shape
# prefix/Reshape_413
# prefix/Reshape_414/shape
# prefix/Reshape_414
# prefix/Reshape_415/shape
# prefix/Reshape_415
# prefix/batchnorm_103/add/y
# prefix/batchnorm_103/add
# prefix/batchnorm_103/Rsqrt
# prefix/batchnorm_103/mul
# prefix/batchnorm_103/mul_1
# prefix/batchnorm_103/mul_2
# prefix/batchnorm_103/sub
# prefix/batchnorm_103/add_1
# prefix/Relu_103
# prefix/transpose_315/perm
# prefix/transpose_315
# prefix/Const_1036
# prefix/Pad_103
# prefix/Const_1037
# prefix/split_206/split_dim
# prefix/split_206
# prefix/transpose_316/perm
# prefix/transpose_316
# prefix/Const_1038
# prefix/split_207/split_dim
# prefix/split_207
# prefix/convolution_103/dilation_rate
# prefix/convolution_103
# prefix/concat_152/concat_dim
# prefix/concat_152
# prefix/transpose_317/perm
# prefix/transpose_317
# prefix/concat_153/axis
# prefix/concat_153
# prefix/Reshape_416/shape
# prefix/Reshape_416
# prefix/Reshape_417/shape
# prefix/Reshape_417
# prefix/Reshape_418/shape
# prefix/Reshape_418
# prefix/Reshape_419/shape
# prefix/Reshape_419
# prefix/batchnorm_104/add/y
# prefix/batchnorm_104/add
# prefix/batchnorm_104/Rsqrt
# prefix/batchnorm_104/mul
# prefix/batchnorm_104/mul_1
# prefix/batchnorm_104/mul_2
# prefix/batchnorm_104/sub
# prefix/batchnorm_104/add_1
# prefix/Relu_104
# prefix/transpose_318/perm
# prefix/transpose_318
# prefix/Const_1039
# prefix/Pad_104
# prefix/Const_1040
# prefix/split_208/split_dim
# prefix/split_208
# prefix/transpose_319/perm
# prefix/transpose_319
# prefix/Const_1041
# prefix/split_209/split_dim
# prefix/split_209
# prefix/convolution_104/dilation_rate
# prefix/convolution_104
# prefix/concat_154/concat_dim
# prefix/concat_154
# prefix/transpose_320/perm
# prefix/transpose_320
# prefix/Reshape_420/shape
# prefix/Reshape_420
# prefix/Reshape_421/shape
# prefix/Reshape_421
# prefix/Reshape_422/shape
# prefix/Reshape_422
# prefix/Reshape_423/shape
# prefix/Reshape_423
# prefix/batchnorm_105/add/y
# prefix/batchnorm_105/add
# prefix/batchnorm_105/Rsqrt
# prefix/batchnorm_105/mul
# prefix/batchnorm_105/mul_1
# prefix/batchnorm_105/mul_2
# prefix/batchnorm_105/sub
# prefix/batchnorm_105/add_1
# prefix/Relu_105
# prefix/transpose_321/perm
# prefix/transpose_321
# prefix/Const_1042
# prefix/Pad_105
# prefix/Const_1043
# prefix/split_210/split_dim
# prefix/split_210
# prefix/transpose_322/perm
# prefix/transpose_322
# prefix/Const_1044
# prefix/split_211/split_dim
# prefix/split_211
# prefix/convolution_105/dilation_rate
# prefix/convolution_105
# prefix/concat_155/concat_dim
# prefix/concat_155
# prefix/transpose_323/perm
# prefix/transpose_323
# prefix/concat_156/axis
# prefix/concat_156
# prefix/Reshape_424/shape
# prefix/Reshape_424
# prefix/Reshape_425/shape
# prefix/Reshape_425
# prefix/Reshape_426/shape
# prefix/Reshape_426
# prefix/Reshape_427/shape
# prefix/Reshape_427
# prefix/batchnorm_106/add/y
# prefix/batchnorm_106/add
# prefix/batchnorm_106/Rsqrt
# prefix/batchnorm_106/mul
# prefix/batchnorm_106/mul_1
# prefix/batchnorm_106/mul_2
# prefix/batchnorm_106/sub
# prefix/batchnorm_106/add_1
# prefix/Relu_106
# prefix/transpose_324/perm
# prefix/transpose_324
# prefix/Const_1045
# prefix/Pad_106
# prefix/Const_1046
# prefix/split_212/split_dim
# prefix/split_212
# prefix/transpose_325/perm
# prefix/transpose_325
# prefix/Const_1047
# prefix/split_213/split_dim
# prefix/split_213
# prefix/convolution_106/dilation_rate
# prefix/convolution_106
# prefix/concat_157/concat_dim
# prefix/concat_157
# prefix/transpose_326/perm
# prefix/transpose_326
# prefix/Reshape_428/shape
# prefix/Reshape_428
# prefix/Reshape_429/shape
# prefix/Reshape_429
# prefix/Reshape_430/shape
# prefix/Reshape_430
# prefix/Reshape_431/shape
# prefix/Reshape_431
# prefix/batchnorm_107/add/y
# prefix/batchnorm_107/add
# prefix/batchnorm_107/Rsqrt
# prefix/batchnorm_107/mul
# prefix/batchnorm_107/mul_1
# prefix/batchnorm_107/mul_2
# prefix/batchnorm_107/sub
# prefix/batchnorm_107/add_1
# prefix/Relu_107
# prefix/transpose_327/perm
# prefix/transpose_327
# prefix/Const_1048
# prefix/Pad_107
# prefix/Const_1049
# prefix/split_214/split_dim
# prefix/split_214
# prefix/transpose_328/perm
# prefix/transpose_328
# prefix/Const_1050
# prefix/split_215/split_dim
# prefix/split_215
# prefix/convolution_107/dilation_rate
# prefix/convolution_107
# prefix/concat_158/concat_dim
# prefix/concat_158
# prefix/transpose_329/perm
# prefix/transpose_329
# prefix/concat_159/axis
# prefix/concat_159
# prefix/Reshape_432/shape
# prefix/Reshape_432
# prefix/Reshape_433/shape
# prefix/Reshape_433
# prefix/Reshape_434/shape
# prefix/Reshape_434
# prefix/Reshape_435/shape
# prefix/Reshape_435
# prefix/batchnorm_108/add/y
# prefix/batchnorm_108/add
# prefix/batchnorm_108/Rsqrt
# prefix/batchnorm_108/mul
# prefix/batchnorm_108/mul_1
# prefix/batchnorm_108/mul_2
# prefix/batchnorm_108/sub
# prefix/batchnorm_108/add_1
# prefix/Relu_108
# prefix/transpose_330/perm
# prefix/transpose_330
# prefix/Const_1051
# prefix/Pad_108
# prefix/Const_1052
# prefix/split_216/split_dim
# prefix/split_216
# prefix/transpose_331/perm
# prefix/transpose_331
# prefix/Const_1053
# prefix/split_217/split_dim
# prefix/split_217
# prefix/convolution_108/dilation_rate
# prefix/convolution_108
# prefix/concat_160/concat_dim
# prefix/concat_160
# prefix/transpose_332/perm
# prefix/transpose_332
# prefix/Reshape_436/shape
# prefix/Reshape_436
# prefix/Reshape_437/shape
# prefix/Reshape_437
# prefix/Reshape_438/shape
# prefix/Reshape_438
# prefix/Reshape_439/shape
# prefix/Reshape_439
# prefix/batchnorm_109/add/y
# prefix/batchnorm_109/add
# prefix/batchnorm_109/Rsqrt
# prefix/batchnorm_109/mul
# prefix/batchnorm_109/mul_1
# prefix/batchnorm_109/mul_2
# prefix/batchnorm_109/sub
# prefix/batchnorm_109/add_1
# prefix/Relu_109
# prefix/transpose_333/perm
# prefix/transpose_333
# prefix/Const_1054
# prefix/Pad_109
# prefix/Const_1055
# prefix/split_218/split_dim
# prefix/split_218
# prefix/transpose_334/perm
# prefix/transpose_334
# prefix/Const_1056
# prefix/split_219/split_dim
# prefix/split_219
# prefix/convolution_109/dilation_rate
# prefix/convolution_109
# prefix/concat_161/concat_dim
# prefix/concat_161
# prefix/transpose_335/perm
# prefix/transpose_335
# prefix/concat_162/axis
# prefix/concat_162
# prefix/Reshape_440/shape
# prefix/Reshape_440
# prefix/Reshape_441/shape
# prefix/Reshape_441
# prefix/Reshape_442/shape
# prefix/Reshape_442
# prefix/Reshape_443/shape
# prefix/Reshape_443
# prefix/batchnorm_110/add/y
# prefix/batchnorm_110/add
# prefix/batchnorm_110/Rsqrt
# prefix/batchnorm_110/mul
# prefix/batchnorm_110/mul_1
# prefix/batchnorm_110/mul_2
# prefix/batchnorm_110/sub
# prefix/batchnorm_110/add_1
# prefix/Relu_110
# prefix/transpose_336/perm
# prefix/transpose_336
# prefix/Const_1057
# prefix/Pad_110
# prefix/Const_1058
# prefix/split_220/split_dim
# prefix/split_220
# prefix/transpose_337/perm
# prefix/transpose_337
# prefix/Const_1059
# prefix/split_221/split_dim
# prefix/split_221
# prefix/convolution_110/dilation_rate
# prefix/convolution_110
# prefix/concat_163/concat_dim
# prefix/concat_163
# prefix/transpose_338/perm
# prefix/transpose_338
# prefix/Reshape_444/shape
# prefix/Reshape_444
# prefix/Reshape_445/shape
# prefix/Reshape_445
# prefix/Reshape_446/shape
# prefix/Reshape_446
# prefix/Reshape_447/shape
# prefix/Reshape_447
# prefix/batchnorm_111/add/y
# prefix/batchnorm_111/add
# prefix/batchnorm_111/Rsqrt
# prefix/batchnorm_111/mul
# prefix/batchnorm_111/mul_1
# prefix/batchnorm_111/mul_2
# prefix/batchnorm_111/sub
# prefix/batchnorm_111/add_1
# prefix/Relu_111
# prefix/transpose_339/perm
# prefix/transpose_339
# prefix/Const_1060
# prefix/Pad_111
# prefix/Const_1061
# prefix/split_222/split_dim
# prefix/split_222
# prefix/transpose_340/perm
# prefix/transpose_340
# prefix/Const_1062
# prefix/split_223/split_dim
# prefix/split_223
# prefix/convolution_111/dilation_rate
# prefix/convolution_111
# prefix/concat_164/concat_dim
# prefix/concat_164
# prefix/transpose_341/perm
# prefix/transpose_341
# prefix/concat_165/axis
# prefix/concat_165
# prefix/Reshape_448/shape
# prefix/Reshape_448
# prefix/Reshape_449/shape
# prefix/Reshape_449
# prefix/Reshape_450/shape
# prefix/Reshape_450
# prefix/Reshape_451/shape
# prefix/Reshape_451
# prefix/batchnorm_112/add/y
# prefix/batchnorm_112/add
# prefix/batchnorm_112/Rsqrt
# prefix/batchnorm_112/mul
# prefix/batchnorm_112/mul_1
# prefix/batchnorm_112/mul_2
# prefix/batchnorm_112/sub
# prefix/batchnorm_112/add_1
# prefix/Relu_112
# prefix/transpose_342/perm
# prefix/transpose_342
# prefix/Const_1063
# prefix/Pad_112
# prefix/Const_1064
# prefix/split_224/split_dim
# prefix/split_224
# prefix/transpose_343/perm
# prefix/transpose_343
# prefix/Const_1065
# prefix/split_225/split_dim
# prefix/split_225
# prefix/convolution_112/dilation_rate
# prefix/convolution_112
# prefix/concat_166/concat_dim
# prefix/concat_166
# prefix/transpose_344/perm
# prefix/transpose_344
# prefix/Reshape_452/shape
# prefix/Reshape_452
# prefix/Reshape_453/shape
# prefix/Reshape_453
# prefix/Reshape_454/shape
# prefix/Reshape_454
# prefix/Reshape_455/shape
# prefix/Reshape_455
# prefix/batchnorm_113/add/y
# prefix/batchnorm_113/add
# prefix/batchnorm_113/Rsqrt
# prefix/batchnorm_113/mul
# prefix/batchnorm_113/mul_1
# prefix/batchnorm_113/mul_2
# prefix/batchnorm_113/sub
# prefix/batchnorm_113/add_1
# prefix/Relu_113
# prefix/transpose_345/perm
# prefix/transpose_345
# prefix/Const_1066
# prefix/Pad_113
# prefix/Const_1067
# prefix/split_226/split_dim
# prefix/split_226
# prefix/transpose_346/perm
# prefix/transpose_346
# prefix/Const_1068
# prefix/split_227/split_dim
# prefix/split_227
# prefix/convolution_113/dilation_rate
# prefix/convolution_113
# prefix/concat_167/concat_dim
# prefix/concat_167
# prefix/transpose_347/perm
# prefix/transpose_347
# prefix/concat_168/axis
# prefix/concat_168
# prefix/Reshape_456/shape
# prefix/Reshape_456
# prefix/Reshape_457/shape
# prefix/Reshape_457
# prefix/Reshape_458/shape
# prefix/Reshape_458
# prefix/Reshape_459/shape
# prefix/Reshape_459
# prefix/batchnorm_114/add/y
# prefix/batchnorm_114/add
# prefix/batchnorm_114/Rsqrt
# prefix/batchnorm_114/mul
# prefix/batchnorm_114/mul_1
# prefix/batchnorm_114/mul_2
# prefix/batchnorm_114/sub
# prefix/batchnorm_114/add_1
# prefix/Relu_114
# prefix/transpose_348/perm
# prefix/transpose_348
# prefix/Const_1069
# prefix/Pad_114
# prefix/Const_1070
# prefix/split_228/split_dim
# prefix/split_228
# prefix/transpose_349/perm
# prefix/transpose_349
# prefix/Const_1071
# prefix/split_229/split_dim
# prefix/split_229
# prefix/convolution_114/dilation_rate
# prefix/convolution_114
# prefix/concat_169/concat_dim
# prefix/concat_169
# prefix/transpose_350/perm
# prefix/transpose_350
# prefix/Reshape_460/shape
# prefix/Reshape_460
# prefix/Reshape_461/shape
# prefix/Reshape_461
# prefix/Reshape_462/shape
# prefix/Reshape_462
# prefix/Reshape_463/shape
# prefix/Reshape_463
# prefix/batchnorm_115/add/y
# prefix/batchnorm_115/add
# prefix/batchnorm_115/Rsqrt
# prefix/batchnorm_115/mul
# prefix/batchnorm_115/mul_1
# prefix/batchnorm_115/mul_2
# prefix/batchnorm_115/sub
# prefix/batchnorm_115/add_1
# prefix/Relu_115
# prefix/transpose_351/perm
# prefix/transpose_351
# prefix/Const_1072
# prefix/Pad_115
# prefix/Const_1073
# prefix/split_230/split_dim
# prefix/split_230
# prefix/transpose_352/perm
# prefix/transpose_352
# prefix/Const_1074
# prefix/split_231/split_dim
# prefix/split_231
# prefix/convolution_115/dilation_rate
# prefix/convolution_115
# prefix/concat_170/concat_dim
# prefix/concat_170
# prefix/transpose_353/perm
# prefix/transpose_353
# prefix/concat_171/axis
# prefix/concat_171
# prefix/Reshape_464/shape
# prefix/Reshape_464
# prefix/Reshape_465/shape
# prefix/Reshape_465
# prefix/Reshape_466/shape
# prefix/Reshape_466
# prefix/Reshape_467/shape
# prefix/Reshape_467
# prefix/batchnorm_116/add/y
# prefix/batchnorm_116/add
# prefix/batchnorm_116/Rsqrt
# prefix/batchnorm_116/mul
# prefix/batchnorm_116/mul_1
# prefix/batchnorm_116/mul_2
# prefix/batchnorm_116/sub
# prefix/batchnorm_116/add_1
# prefix/Relu_116
# prefix/transpose_354/perm
# prefix/transpose_354
# prefix/Const_1075
# prefix/Pad_116
# prefix/Const_1076
# prefix/split_232/split_dim
# prefix/split_232
# prefix/transpose_355/perm
# prefix/transpose_355
# prefix/Const_1077
# prefix/split_233/split_dim
# prefix/split_233
# prefix/convolution_116/dilation_rate
# prefix/convolution_116
# prefix/concat_172/concat_dim
# prefix/concat_172
# prefix/transpose_356/perm
# prefix/transpose_356
# prefix/Reshape_468/shape
# prefix/Reshape_468
# prefix/Reshape_469/shape
# prefix/Reshape_469
# prefix/Reshape_470/shape
# prefix/Reshape_470
# prefix/Reshape_471/shape
# prefix/Reshape_471
# prefix/batchnorm_117/add/y
# prefix/batchnorm_117/add
# prefix/batchnorm_117/Rsqrt
# prefix/batchnorm_117/mul
# prefix/batchnorm_117/mul_1
# prefix/batchnorm_117/mul_2
# prefix/batchnorm_117/sub
# prefix/batchnorm_117/add_1
# prefix/Relu_117
# prefix/transpose_357/perm
# prefix/transpose_357
# prefix/Const_1078
# prefix/Pad_117
# prefix/Const_1079
# prefix/split_234/split_dim
# prefix/split_234
# prefix/transpose_358/perm
# prefix/transpose_358
# prefix/Const_1080
# prefix/split_235/split_dim
# prefix/split_235
# prefix/convolution_117/dilation_rate
# prefix/convolution_117
# prefix/concat_173/concat_dim
# prefix/concat_173
# prefix/transpose_359/perm
# prefix/transpose_359
# prefix/concat_174/axis
# prefix/concat_174
# prefix/Reshape_472/shape
# prefix/Reshape_472
# prefix/Reshape_473/shape
# prefix/Reshape_473
# prefix/Reshape_474/shape
# prefix/Reshape_474
# prefix/Reshape_475/shape
# prefix/Reshape_475
# prefix/batchnorm_118/add/y
# prefix/batchnorm_118/add
# prefix/batchnorm_118/Rsqrt
# prefix/batchnorm_118/mul
# prefix/batchnorm_118/mul_1
# prefix/batchnorm_118/mul_2
# prefix/batchnorm_118/sub
# prefix/batchnorm_118/add_1
# prefix/Relu_118
# prefix/transpose_360/perm
# prefix/transpose_360
# prefix/Const_1081
# prefix/Pad_118
# prefix/Const_1082
# prefix/split_236/split_dim
# prefix/split_236
# prefix/transpose_361/perm
# prefix/transpose_361
# prefix/Const_1083
# prefix/split_237/split_dim
# prefix/split_237
# prefix/convolution_118/dilation_rate
# prefix/convolution_118
# prefix/concat_175/concat_dim
# prefix/concat_175
# prefix/transpose_362/perm
# prefix/transpose_362
# prefix/Reshape_476/shape
# prefix/Reshape_476
# prefix/Reshape_477/shape
# prefix/Reshape_477
# prefix/Reshape_478/shape
# prefix/Reshape_478
# prefix/Reshape_479/shape
# prefix/Reshape_479
# prefix/batchnorm_119/add/y
# prefix/batchnorm_119/add
# prefix/batchnorm_119/Rsqrt
# prefix/batchnorm_119/mul
# prefix/batchnorm_119/mul_1
# prefix/batchnorm_119/mul_2
# prefix/batchnorm_119/sub
# prefix/batchnorm_119/add_1
# prefix/Relu_119
# prefix/transpose_363/perm
# prefix/transpose_363
# prefix/Const_1084
# prefix/Pad_119
# prefix/Const_1085
# prefix/split_238/split_dim
# prefix/split_238
# prefix/transpose_364/perm
# prefix/transpose_364
# prefix/Const_1086
# prefix/split_239/split_dim
# prefix/split_239
# prefix/convolution_119/dilation_rate
# prefix/convolution_119
# prefix/concat_176/concat_dim
# prefix/concat_176
# prefix/transpose_365/perm
# prefix/transpose_365
# prefix/concat_177/axis
# prefix/concat_177
# prefix/Reshape_480/shape
# prefix/Reshape_480
# prefix/Reshape_481/shape
# prefix/Reshape_481
# prefix/Reshape_482/shape
# prefix/Reshape_482
# prefix/Reshape_483/shape
# prefix/Reshape_483
# prefix/batchnorm_120/add/y
# prefix/batchnorm_120/add
# prefix/batchnorm_120/Rsqrt
# prefix/batchnorm_120/mul
# prefix/batchnorm_120/mul_1
# prefix/batchnorm_120/mul_2
# prefix/batchnorm_120/sub
# prefix/batchnorm_120/add_1
# prefix/Relu_120
# prefix/transpose_366/perm
# prefix/transpose_366
# prefix/avg_pool_3/dilation_rate
# prefix/avg_pool_3
# prefix/transpose_367/perm
# prefix/transpose_367
# prefix/Const_1087
# prefix/Shape
# prefix/GatherV2/axis
# prefix/GatherV2
# prefix/Const_1088
# prefix/ExpandDims/dim
# prefix/ExpandDims
# prefix/ExpandDims_1/dim
# prefix/ExpandDims_1
# prefix/concat_178/axis
# prefix/concat_178
# prefix/Shape_1
# prefix/Const_1089
# prefix/Equal
# prefix/Where
# prefix/Squeeze
# prefix/GatherV2_1/axis
# prefix/GatherV2_1
# prefix/Shape_2
# prefix/Cast
# prefix/SparseToDense/default_value
# prefix/SparseToDense
# prefix/add
# prefix/Reshape_484
# prefix/flatten/Shape
# prefix/flatten/strided_slice/stack
# prefix/flatten/strided_slice/stack_1
# prefix/flatten/strided_slice/stack_2
# prefix/flatten/strided_slice
# prefix/flatten/Reshape/shape/1
# prefix/flatten/Reshape/shape
# prefix/flatten/Reshape
# prefix/transpose_368/Rank
# prefix/transpose_368/sub/y
# prefix/transpose_368/sub
# prefix/transpose_368/Range/start
# prefix/transpose_368/Range/delta
# prefix/transpose_368/Range
# prefix/transpose_368/sub_1
# prefix/transpose_368
# prefix/MatMul
# prefix/mul/x
# prefix/mul
# prefix/mul_1/x
# prefix/mul_1
# prefix/add_1
# prefix/Sigmoid

# %%
# !tensorflowjs_converter --help
# Out:
# Using TensorFlow backend.
# usage: TensorFlow.js model converters. [-h]
#                                        [--input_format {tensorflowjs,tf_frozen_model,keras,tf_hub,keras_saved_model,tf_saved_model,tf_session_bundle}]
#                                        [--output_format {tensorflowjs,keras}]
#                                        [--output_node_names OUTPUT_NODE_NAMES]
#                                        [--signature_name SIGNATURE_NAME]
#                                        [--saved_model_tags SAVED_MODEL_TAGS]
#                                        [--quantization_bytes {1,2}]
#                                        [--split_weights_by_layer] [--version]
#                                        [--skip_op_check SKIP_OP_CHECK]
#                                        [--strip_debug_ops STRIP_DEBUG_OPS]
#                                        [input_path] [output_path]
#
# positional arguments:
#   input_path            Path to the input file or directory. For input format
#                         "keras", an HDF5 (.h5) file is expected. For input
#                         format "tensorflow", a SavedModel directory, session
#                         bundle directory, frozen model file, or TF-Hub module
#                         is expected.
#   output_path           Path for all output artifacts.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --input_format {tensorflowjs,tf_frozen_model,keras,tf_hub,keras_saved_model,tf_saved_model,tf_session_bundle}
#                         Input format. For "keras", the input path can be one
#                         of the two following formats: - A topology+weights
#                         combined HDF5 (e.g., generated with
#                         `keras.model.save_model()` method). - A weights-only
#                         HDF5 (e.g., generated with Keras Model's
#                         `save_weights()` method). For "keras_saved_model", the
#                         input_path must point to a subfolder under the saved
#                         model folder that is passed as the argument to
#                         tf.contrib.save_model.save_keras_model(). The
#                         subfolder is generated automatically by tensorflow
#                         when saving tf.keras model in the SavedModel format.
#                         It is usually named as a Unix epoch time (e.g.,
#                         1542212752). For "tf" formats, a SavedModel, frozen
#                         model, session bundle model, or TF-Hub module is
#                         expected.
#   --output_format {tensorflowjs,keras}
#                         Output format. Default: tensorflowjs.
#   --output_node_names OUTPUT_NODE_NAMES
#                         The names of the output nodes, separated by commas.
#                         E.g., "logits,activations". Applicable only if input
#                         format is "tf_saved_model" or "tf_session_bundle".
#   --signature_name SIGNATURE_NAME
#                         Signature of the TF-Hub module to load. Applicable
#                         only if input format is "tf_hub".
#   --saved_model_tags SAVED_MODEL_TAGS
#                         Tags of the MetaGraphDef to load, in comma separated
#                         string format. Defaults to "serve". Applicable only if
#                         input format is "tf_saved_model".
#   --quantization_bytes {1,2}
#                         How many bytes to optionally quantize/compress the
#                         weights to. 1- and 2-byte quantizaton is supported.
#                         The default (unquantized) size is 4 bytes.
#   --split_weights_by_layer
#                         Applicable to keras input_format only: Whether the
#                         weights from different layers are to be stored in
#                         separate weight groups, corresponding to separate
#                         binary weight files. Default: False.
#   --version, -v         Show versions of tensorflowjs and its dependencies
#   --skip_op_check SKIP_OP_CHECK
#                         Skip op validation for TensorFlow model conversion.
#   --strip_debug_ops STRIP_DEBUG_OPS
#                         Strip debug ops (Print, Assert, CheckNumerics) from
#                         graph.

# %%
#!rm -rf test2

# %%
# !git clone https://github.com/tensorflow/tfjs-converter
# !tensorflowjs_converter \
    --input_format=tf_frozen_model \
    --output_node_names='Sigmoid' \
    --quantization_bytes 2 \
    chest.pb \
    chestxnet_b2
# Out:
# Using TensorFlow backend.
# 2019-01-06 20:12:34.836519: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:501] Optimization results for grappler item: graph_to_optimize
# 2019-01-06 20:12:34.836546: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   debug_stripper: Graph size after: 5140 nodes (0), 4716 edges (0), time = 27.949ms.
# 2019-01-06 20:12:34.836552: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   model_pruner: Graph size after: 4414 nodes (-726), 4596 edges (-120), time = 71.415ms.
# 2019-01-06 20:12:34.836556: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   constant folding: Graph size after: 1967 nodes (-2447), 2024 edges (-2572), time = 529.012ms.
# 2019-01-06 20:12:34.836560: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   arithmetic_optimizer: Graph size after: 1424 nodes (-543), 2024 edges (0), time = 139.486ms.
# 2019-01-06 20:12:34.836564: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   dependency_optimizer: Graph size after: 1225 nodes (-199), 1639 edges (-385), time = 34.443ms.
# 2019-01-06 20:12:34.836636: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   model_pruner: Graph size after: 1225 nodes (0), 1639 edges (0), time = 19.973ms.
# 2019-01-06 20:12:34.836641: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   remapper: Graph size after: 1225 nodes (0), 1639 edges (0), time = 20.105ms.
# 2019-01-06 20:12:34.836645: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   constant folding: Graph size after: 1225 nodes (0), 1639 edges (0), time = 119.102ms.
# 2019-01-06 20:12:34.836649: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   arithmetic_optimizer: Graph size after: 1225 nodes (0), 1639 edges (0), time = 104.046ms.
# 2019-01-06 20:12:34.836653: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   dependency_optimizer: Graph size after: 1225 nodes (0), 1639 edges (0), time = 30.959ms.
# 2019-01-06 20:12:34.836657: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   debug_stripper: Graph size after: 1225 nodes (0), 1639 edges (0), time = 18.222ms.
# 2019-01-06 20:12:34.836881: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   model_pruner: Graph size after: 1225 nodes (0), 1639 edges (0), time = 19.973ms.
# 2019-01-06 20:12:34.836887: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   constant folding: Graph size after: 1225 nodes (0), 1639 edges (0), time = 130.774ms.
# 2019-01-06 20:12:34.836891: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   arithmetic_optimizer: Graph size after: 1225 nodes (0), 1639 edges (0), time = 119.607ms.
# 2019-01-06 20:12:34.836894: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   dependency_optimizer: Graph size after: 1225 nodes (0), 1639 edges (0), time = 33.584ms.
# 2019-01-06 20:12:34.836898: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   model_pruner: Graph size after: 1225 nodes (0), 1639 edges (0), time = 21.187ms.
# 2019-01-06 20:12:34.836902: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   remapper: Graph size after: 1225 nodes (0), 1639 edges (0), time = 20.495ms.
# 2019-01-06 20:12:34.837052: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   constant folding: Graph size after: 1225 nodes (0), 1639 edges (0), time = 119.774ms.
# 2019-01-06 20:12:34.837058: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   arithmetic_optimizer: Graph size after: 1225 nodes (0), 1639 edges (0), time = 112.863ms.
# 2019-01-06 20:12:34.837061: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:503]   dependency_optimizer: Graph size after: 1225 nodes (0), 1639 edges (0), time = 31.729ms.
# Writing weight file chestxnet_b2/tensorflowjs_model.pb...
# 2019-01-06 20:12:35.014677: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA

# %%
# !scp -r chestxnet_b2 jcccnetc@jcccnet.com:www/mlmed/tools-dev/xray/models/chestxnet_b2
# Out:
# group1-shard4of4                              100% 1322KB 439.3KB/s   00:03
# group1-shard1of4                              100% 4096KB 408.7KB/s   00:10
# weights_manifest.json                         100%   62KB 291.0KB/s   00:00
# tensorflowjs_model.pb                         100%   97KB 326.5KB/s   00:00
# group1-shard2of4                              100% 4096KB 408.7KB/s   00:10
# group1-shard3of4                              100% 4096KB 408.8KB/s   00:10
